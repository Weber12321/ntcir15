# %% [markdown]
# # NTCIR-15 DialEval model note
# ###### Created by Weber Huang 2020-06-15

# %% [markdown]
# ## Table of content
# #### 1. JSON to dataframe
# #### 2. Dataset cleaning
# #### 3. Segmentation
# #### 4. Generate the output of preprocessing
# #### 5. Modeling
# #### 6. Evaluation
# #### 7. Generate the submission estimation JSON

# %% [markdown]
# > How to use this note?
#
# + In this ipython file, the model will be train autometically. Feel free to adjust the parameter of those models If you want. I'd suggest you to directly switch to section 5.
# + If you want to test the evaluation, here is the way:
#     1. Run the cell to section 4 first, use **generate_dataset(name, wd, stop_word_path)** to process raw json to dataframe for both train and dev.
#     2. Run section 5 and 6.
#     3. In section 6, there is a function **Generate_submission(dev, model_1, model_2)**, plz make sure that both 2 model are same, like both are cnn or lst.
#     4. Save the submission copy and test it with ground_truth through eval.py

# %%
import os
import pandas as pd
from tqdm import tqdm_notebook as tqdm
import numpy as np
from collections import Counter
from sklearn import preprocessing
import jieba
import re

# %% [markdown]
# ### 1.JSON to dataframe

# %%
def get_nugget(dataframe):   
    target = {'nugget'}
    dicts = []
    for item in tqdm(dataframe['annotations']):
        sub_dicts = []
        for element in item:
            sub_dicts.append({key:value for key,value in element.items() if key in target}['nugget'])
        dicts.append(sub_dicts)

    dataframe['nuggets'] = dicts # dis is for anno nugget list
    
    return dataframe

def shaping(dataframe):
    length = []
    for i in tqdm(dataframe['turns']):
        length.append(len(i))
    Id = dataframe['id'].tolist()

    Fin_Id = sum([[s] * n for s, n in zip(Id, length)], [])

    turns_list = dataframe['turns'].tolist()
    
    Fin_turns_anno = []
    for x,y in tqdm(zip(turns_list,dataframe['nuggets'])):
        for q in range(len(x)):
            Fin_turns_anno.append(list(x[q].values())+[i[q] for i in y])
    
    return Fin_Id, Fin_turns_anno

def stacking(Fin_Id, Fin_turns_anno):    
    train_clean = pd.DataFrame({'id': Fin_Id,'info': Fin_turns_anno})
    # train_clean.head()
    train_df = pd.DataFrame(train_clean['info'].values.tolist(), columns=['sender','utterance','n1','n2','n3','n4','n5','n6','n7','n8','n9','n10','n11','n12','n13','n14','n15','n16','n17','n18','n19'])
    train_df['id'] = train_clean['id']
    train_df = train_df[['id','sender','utterance','n1','n2','n3','n4','n5','n6','n7','n8','n9','n10','n11','n12','n13','n14','n15','n16','n17','n18','n19']]
    
    return train_df

# %% [markdown]
# ### 2.Dataset cleaning

# %%
def process_data(dataframe):
    
    # id to str
    dataframe['id'] = dataframe['id'].apply(str)
    
    
    # round
    uni = dataframe.id.unique()
    num = []
    for i in uni:
        count = 1
        for j in dataframe['id']:
            if i == j:
                num.append(count)
                count += 1
            else:
                continue

    dataframe['round'] = num
    
    
    # distribution
    Nugget_types = ['CNUG0', 'CNUG', 'CNUG*', 'CNaN','HNUG', 'HNUG*', 'HNaN']
    arr = np.array(dataframe.iloc[:,3:22]) 
    dicts = []
    tmp = []
    
    for i in arr:
        c = Counter(i)
        dicts.append(c)
        
    for i in dicts:
        test = []
        for n in Nugget_types:
            test.append(i.get(n,0)/19)
        tmp.append(test)
        
    tmp = np.array(tmp)
    for i in range(len(Nugget_types)):
        dataframe[Nugget_types[i]] = tmp[:,i]
        
        
    # round_max (round_label)
    f = dataframe.groupby('round').sum()
    out = list(f.idxmax(axis=1))

    round_max = []
    for i in dataframe['round']:
        for j in range(1,8):
            if i == j:
                round_max.append(out[j-1])
            else:
                continue
    dataframe['round_max'] = round_max
    
    
    # label encoding (round_label)
    
    le = preprocessing.LabelEncoder()
    le.fit(Nugget_types);
    round_label = le.transform(list(dataframe['round_max']))
    dataframe['round_label'] = round_label
    
    
    # label encoding (sender_num)
    sender = ['customer','helpdesk']
    l = preprocessing.LabelEncoder()
    l.fit(sender);
    sender_num = l.transform(list(dataframe['sender']))
    dataframe['sender_num'] = sender_num
    
    subset = dataframe[['id','sender','sender_num','utterance','round','round_max','round_label',
                        'CNUG0', 'CNUG', 'CNUG*', 'CNaN','HNUG', 'HNUG*', 'HNaN']]
    
    return subset

# %% [markdown]
# ### 3.Segmentation

# %%
def segment(dataframe, file_path):
    
    texts = dataframe['utterance'].astype(str)
    
    seg_texts = []
    for line in texts:
        seg_content = ' '.join(jieba.cut(line, cut_all = False))
        seg_texts.append(seg_content)
        
    def remove_punctuation(line):
        rule = re.compile("[^a-zA-Z0-9\u4e00-\u9fa5]")
        line = rule.sub(' ',line)
        return line
    
    texts = []
    for line in seg_texts:
        new_line = remove_punctuation(line).split()
        texts.append(new_line)
        
    cn_stopwords = []
    with open(file_path, 'r', encoding='UTF-8') as file:
        for data in file.read().splitlines():
            cn_stopwords.append(data)
            
    # remove punctuation
    pp_texts = []
    for line in texts:
        line_noSW = []
        for word in line:
            if word not in cn_stopwords:
                line_noSW.append(word)
        pp_texts.append(line_noSW)
    
    # change emoji in pp_texts to *
    for line in pp_texts:
        if line == []:
            line.append("*")
            
    # concatenate the sentences by whitespace
    new_texts = []
    for sentence in pp_texts:
        series_sentence = " ".join(word for word in sentence)
        new_texts.append(series_sentence)
    
    dataframe['texts'] = new_texts
    
    subset = dataframe[['id','sender','sender_num','texts','round','round_max','round_label',
                        'CNUG0', 'CNUG', 'CNUG*', 'CNaN','HNUG', 'HNUG*', 'HNaN']]
    
    return subset

# %% [markdown]
# ### 4.Generate the output of preprocessing

# %%
def generate_dataset(name, wd, stop_word_path):
    os.chdir(wd)
    file = pd.read_json(name, encoding='utf8')
    nu = get_nugget(file)
    Id, anno = shaping(nu)
    output = stacking(Id, anno)
    fin = process_data(output)
    seg = segment(fin, stop_word_path)
    
    return seg

# %% [markdown]
# ###### Plz feed the raw_json, working directory and stop_word file in the generate_dataset()

# %%
# save file
# import time
# path = 'C:/Users/doudi/OneDrive/Documents/stc3-dataset/data/'
# timestr = time.strftime("%Y%m%d%H%M")
# output.to_csv((path + timestr + '_train_data_cn.csv'), index=False, encoding='utf_8_sig')

# %%
train = generate_dataset(r'train_cn.json',
                          'C:/Users/doudi/OneDrive/Documents/ntcir15/Dataset/New_DialEval-1',
                         'C:/Users/doudi/OneDrive/Documents/ntcir15/Dataset/DialEval-1/cn_stopwords.txt')
# Out:
# C:\Users\doudi\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
# HBox(children=(FloatProgress(value=0.0, max=3700.0), HTML(value='')))
# C:\Users\doudi\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   app.launch_new_instance()
# HBox(children=(FloatProgress(value=0.0, max=3700.0), HTML(value='')))
# C:\Users\doudi\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# C:\Users\doudi\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dev = generate_dataset(r'dev_cn.json',
                          'C:/Users/doudi/OneDrive/Documents/ntcir15/Dataset/New_DialEval-1',
                         'C:/Users/doudi/OneDrive/Documents/ntcir15/Dataset/DialEval-1/cn_stopwords.txt')
# Out:
# C:\Users\doudi\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
# HBox(children=(FloatProgress(value=0.0, max=390.0), HTML(value='')))
# C:\Users\doudi\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   app.launch_new_instance()
# HBox(children=(FloatProgress(value=0.0, max=390.0), HTML(value='')))
# C:\Users\doudi\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# C:\Users\doudi\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# > See if the file are same

# %%
# count = 0
# if output.equals(output_15_tr) == True:
#     print("DialEval-14 training data is as same as DialEval-15 training data")
# else:
#     print("DialEval-14 training data is not as same as DialEval-15 training data")

    
# output.iloc[0] == output_15_tr.iloc[0]

# # print("There are {0} rows in 2 datasets as same".format(count))
# # print("\n")
# # print("There are {0} rows in 2 datasets as different".format((len(output)-count)))

# %% [markdown]
# ### 5. Modeling

# %% [markdown]
# #### 5.1 Write some necessory def function

# %%
from scipy import stats
import tensorflow as tf

def normalize(pred, truth):
    """ convert inputs to np.array and make sure
    inputs are normalized probability distributions
    """
    if len(pred) != len(truth):
        raise ValueError("pred and truth have different lengths")
    if len(pred) == 0 or len(truth) == 0:
        raise ValueError("pred or truth are empty")

    pred, truth = np.asarray(pred), np.asarray(truth)
    if not ((pred >= 0).all() and (truth >= 0).all()):
        raise ValueError("probability distribution should not be negative")
    pred, truth = pred / pred.sum(), truth / truth.sum()
    return pred, truth

def jensen_shannon_div(pred, truth, base=2):
    ''' JSD: Jensen-Shannon Divergence
    '''
    pred, truth = normalize(pred, truth)
    m = 1. / 2 * (pred + truth)
    return (stats.entropy(pred, m, base=base)
            + stats.entropy(truth, m, base=base)) / 2.

def root_normalized_squared_error(pred, truth):
    """ RNSS: Root Normalised Sum of Squares
    """

    def squared_error(pred, truth):
        return ((pred - truth) ** 2).sum()

    pred, truth = normalize(pred, truth)
    return np.sqrt(squared_error(pred, truth) / 2)

def jsd_custom_loss(y_true, y_pred):
            
    # calculate loss, using y_pred
    ''' JSD: Jensen-Shannon Divergence
    '''
#     y_pred, y_true = normalize(y_pred, y_true)
    m = 1. / 2 * (y_pred + y_true)
    # loss = (stats.entropy(y_pred, m, base=2) + stats.entropy(y_true, m, base=2)) / 2.
    # tf.keras.losses.KLD()
    loss = (tf.keras.losses.KLD(y_pred, m) + tf.keras.losses.KLD(y_true, m)) / 2.
    return loss
  
# model.compile(loss=jsd_custom_loss, optimizer='adam')

# def rnss_custom_loss(y_true, y_pred):
            
#     # calculate loss, using y_pred
#     """ RNSS: Root Normalised Sum of Squares
#     """

#     def squared_error(y_pred, y_true):
#         return ((y_pred - y_true) ** 2).sum()

# #     y_pred, y_true = normalize(y_pred, y_true)
#     loss = np.sqrt(squared_error(y_pred, y_true) / 2)
    
#     return loss

# %%
# split from sender
train_c = train[train.sender=='customer']
train_h = train[train.sender=='helpdesk']
dev_c = dev[dev.sender=='customer']
dev_h = dev[dev.sender=='helpdesk']

# %%
from sklearn.model_selection import train_test_split 
from sklearn import metrics
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.utils import np_utils
from keras import optimizers
from keras.layers.merge import concatenate
from keras.models import Sequential, Model
from keras.layers import Input
from keras.layers import Dense, Embedding
from keras.layers import Convolution1D, Flatten, Dropout, MaxPool1D, GlobalAveragePooling1D
from keras.layers import concatenate
from keras import initializers
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.embeddings import Embedding
# from keras.layers.recurrent import SimpleRNN
from keras.layers.recurrent import LSTM

# %% [markdown]
# #### 5.2 Features preparation

# %%
# === customer
c_X_train = train_c.filter(['round','round_label','texts'])
c_X_test = dev_c.filter(['round','round_label','texts'])
    

y_train_c = train_c.filter(['CNUG','CNUG*','CNUG0','CNaN'])
y_test_c = dev_c.filter(['CNUG','CNUG*','CNUG0','CNaN'])

# y_train_h = train.filter(['HNUG','HNUG*','HNaN'])
# y_test_h = dev.filter(['HNUG','HNUG*','HNaN'])

c_X1_train = c_X_train['texts']
# c_X1_train = [str (item) for item in c_X1_train]
c_X1_test = c_X_test['texts']
# c_X1_test = [str (item) for item in c_X1_test]

c_X2_train = c_X_train[['round','round_label']].values
c_X2_test = c_X_test[['round','round_label']].values

c_token = Tokenizer(num_words = 20000)
c_token.fit_on_texts(c_X1_train)
c_vocab = c_token.word_index
print(c_token.document_count)

c_x_train_seq = c_token.texts_to_sequences(c_X1_train)
c_x_test_seq = c_token.texts_to_sequences(c_X1_test)
c_X1_train = sequence.pad_sequences(c_x_train_seq, maxlen = 150)
c_X1_test = sequence.pad_sequences(c_x_test_seq, maxlen = 150)
# Out:
# 8500

# %%
# === helpdesk
h_X_train = train_h.filter(['round','round_label','texts'])
h_X_test = dev_h.filter(['round','round_label','texts'])
    

# y_train_c = train_c.filter(['CNUG','CNUG*','CNUG0','CNaN'])
# y_test_c = dev_c.filter(['CNUG','CNUG*','CNUG0','CNaN'])

y_train_h = train_h.filter(['HNUG','HNUG*','HNaN'])
y_test_h = dev_h.filter(['HNUG','HNUG*','HNaN'])

h_X1_train = h_X_train['texts']
# h_X1_train = [str (item) for item in h_X1_train]
h_X1_test = h_X_test['texts']
# h_X1_test = [str (item) for item in h_X1_test]

h_X2_train = h_X_train[['round','round_label']].values
h_X2_test = h_X_test[['round','round_label']].values

h_token = Tokenizer(num_words = 20000)
h_token.fit_on_texts(h_X1_train)
h_vocab = h_token.word_index
print(h_token.document_count)

h_x_train_seq = h_token.texts_to_sequences(h_X1_train)
h_x_test_seq = h_token.texts_to_sequences(h_X1_test)
h_X1_train = sequence.pad_sequences(h_x_train_seq, maxlen = 150)
h_X1_test = sequence.pad_sequences(h_x_test_seq, maxlen = 150)
# Out:
# 6900

# %% [markdown]
# #### 5.3 textCNN for customer and helpdesk respectively

# %%
# === customer
def CNN_C(X1_train, X2_train, X1_test, X2_test, y_train, y_test, loss='categorical_crossentropy'):   
    
    num_labels = 4
    main_input = Input(shape=(150,), dtype='float64')

    sub_input = Input(shape=(2,))
    
    # pre-train embeddings
    # embedder = Embedding(len(vocab) + 1, 300, input_length = 20, weights = [embedding_matrix], trainable = False)
    # embed = embedder(main_input)
    embed = Embedding(len(c_vocab)+1, 300, input_length=150)(main_input)
    # filter size, region size
    cnn = Convolution1D(2, 2, padding='same', strides = 1, activation='relu')(embed)
    cnn = MaxPool1D(pool_size=4)(cnn)
    flat = Flatten()(cnn)
    drop = Dropout(0.2)(flat)
    # main_output = Dense(num_labels, activation='sigmoid')(drop)


    dense_1 = Dense(units=256,activation='relu')(sub_input)
    drop_1 = Dropout(0.35)(dense_1)
    dense_2 = Dense(units=128,activation='relu')(drop_1)
    # sub_output = Dense(units=2,activation='sigmoid')(dense_2)

    merge = concatenate([drop, dense_2])
    dense_3 = Dense(units=10, activation='relu')(merge)
    output = Dense(units=4, activation='softmax')(dense_3)

    model = Model(inputs=[main_input, sub_input], outputs=output)
    model.compile(optimizer='adam', loss=loss, metrics=['accuracy'])
    print(model.summary())

    # checkpoint
    # filepath="C:/Users/doudi/OneDrive/Documents/TMU-GIDS/Lab/Competition/AI cup 2019/weights.best.hdf5"
    # checkpoint= ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    train_history = model.fit(x=[X1_train, X2_train], y=y_train, epochs=100, 
                              batch_size=64, verbose=2, validation_split=0.2)

    score = model.evaluate(x=[X1_test, X2_test], y=y_test, verbose=1)

    print("Test Score:", score[0])
    print("Test Accuracy:", score[1])

    pre_probability = model.predict(x=[X1_test, X2_test])
    predicted = pre_probability.argmax(axis=-1)
    
    return model, train_history, pre_probability

# %%
# === helpdesk
def CNN_H(X1_train, X2_train, X1_test, X2_test, y_train, y_test, loss='categorical_crossentropy'):
    
    num_labels = 2
    main_input = Input(shape=(150,), dtype='float64')

    sub_input = Input(shape=(2,))
    
    # pre-train embeddings
    # embedder = Embedding(len(vocab) + 1, 300, input_length = 20, weights = [embedding_matrix], trainable = False)
    # embed = embedder(main_input)
    embed = Embedding(len(h_vocab)+1, 300, input_length=150)(main_input)
    # filter size, region size
    cnn = Convolution1D(2, 2, padding='same', strides = 1, activation='relu')(embed)
    cnn = MaxPool1D(pool_size=4)(cnn)
    flat = Flatten()(cnn)
    drop = Dropout(0.2)(flat)
    # main_output = Dense(num_labels, activation='sigmoid')(drop)


    dense_1 = Dense(units=256,activation='relu')(sub_input)
    drop_1 = Dropout(0.35)(dense_1)
    dense_2 = Dense(units=128,activation='relu')(drop_1)
    # sub_output = Dense(units=2,activation='sigmoid')(dense_2)

    merge = concatenate([drop, dense_2])
    dense_3 = Dense(units=10, activation='relu')(merge)
    output = Dense(units=3, activation='softmax')(dense_3)

    model = Model(inputs=[main_input, sub_input], outputs=output)
    model.compile(optimizer='adam', loss=loss, metrics=['accuracy'])
    print(model.summary())

    # checkpoint
    # filepath="C:/Users/doudi/OneDrive/Documents/TMU-GIDS/Lab/Competition/AI cup 2019/weights.best.hdf5"
    # checkpoint= ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    train_history = model.fit(x=[X1_train, X2_train], y=y_train, epochs=100, 
                              batch_size=64, verbose=2, validation_split=0.2)

    score = model.evaluate(x=[X1_test, X2_test], y=y_test, verbose=1)

    print("Test Score:", score[0])
    print("Test Accuracy:", score[1])

    pre_probability = model.predict(x=[X1_test, X2_test])
    predicted = pre_probability.argmax(axis=-1)
    
    return model, train_history, pre_probability

# %% [markdown]
# #### 5.4 LSTM for customer and helpdesk respectively

# %%
# === customer
def lstm_C(X1_train, X2_train, X1_test, X2_test, y_train, y_test, loss='categorical_crossentropy'):
     
    main_input = Input(shape=(150,), dtype='float64')
    sub_input = Input(shape=(2,))
    
    embed = Embedding(output_dim=32,input_dim=20000,input_length=150)(main_input)
    dropout_1 = Dropout(0.35)(embed)
    lst = LSTM(units=16)(dropout_1)
    dense_1 = Dense(units=256,activation='relu')(lst)
    dropout_2 = Dropout(0.35)(dense_1)
    dense_2 = Dense(units=128,activation='relu')(dropout_2)
    dense_3 = Dense(units=4,activation='softmax')(dense_2)


    dense_4 = Dense(units=256,activation='relu')(sub_input)
    dropout_3 = Dropout(0.35)(dense_4)
    dense_5 = Dense(units=128,activation='relu')(dropout_3)
    # sub_output = Dense(units=2,activation='sigmoid')(dense_2)

    merge = concatenate([dense_3, dense_5])
    dense_6 = Dense(units=10, activation='relu')(merge)
    output = Dense(units=4, activation='softmax')(dense_6)

    model = Model(inputs=[main_input, sub_input], outputs=output)
    model.compile(optimizer='adam', loss=loss, metrics=['accuracy'])
    print(model.summary())

    # checkpoint
    # filepath="C:/Users/doudi/OneDrive/Documents/TMU-GIDS/Lab/Competition/AI cup 2019/weights.best.hdf5"
    # checkpoint= ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    train_history = model.fit(x=[X1_train, X2_train], y=y_train, epochs=100, 
                              batch_size=64, verbose=2, validation_split=0.2)

    score = model.evaluate(x=[X1_test, X2_test], y=y_test, verbose=1)

    print("Test Score:", score[0])
    print("Test Accuracy:", score[1])

    pre_probability = model.predict(x=[X1_test, X2_test])
    predicted = pre_probability.argmax(axis=-1)
    
    return model, train_history, pre_probability

# %%
# === helpdesk
def lstm_H(X1_train, X2_train, X1_test, X2_test, y_train, y_test, loss='categorical_crossentropy'):
     
    main_input = Input(shape=(150,), dtype='float64')
    sub_input = Input(shape=(2,))
    
    embed = Embedding(output_dim=32,input_dim=20000,input_length=150)(main_input)
    dropout_1 = Dropout(0.35)(embed)
    lst = LSTM(units=16)(dropout_1)
    dense_1 = Dense(units=256,activation='relu')(lst)
    dropout_2 = Dropout(0.35)(dense_1)
    dense_2 = Dense(units=128,activation='relu')(dropout_2)
    dense_3 = Dense(units=3,activation='softmax')(dense_2)


    dense_4 = Dense(units=256,activation='relu')(sub_input)
    dropout_3 = Dropout(0.35)(dense_4)
    dense_5 = Dense(units=128,activation='relu')(dropout_3)
    # sub_output = Dense(units=2,activation='sigmoid')(dense_2)

    merge = concatenate([dense_3, dense_5])
    dense_6 = Dense(units=10, activation='relu')(merge)
    output = Dense(units=3, activation='softmax')(dense_6)

    model = Model(inputs=[main_input, sub_input], outputs=output)
    model.compile(optimizer='adam', loss=loss, metrics=['accuracy'])
    print(model.summary())

    # checkpoint
    # filepath="C:/Users/doudi/OneDrive/Documents/TMU-GIDS/Lab/Competition/AI cup 2019/weights.best.hdf5"
    # checkpoint= ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    train_history = model.fit(x=[X1_train, X2_train], y=y_train, epochs=100, 
                              batch_size=64, verbose=2, validation_split=0.2)

    score = model.evaluate(x=[X1_test, X2_test], y=y_test, verbose=1)

    print("Test Score:", score[0])
    print("Test Accuracy:", score[1])

    pre_probability = model.predict(x=[X1_test, X2_test])
    predicted = pre_probability.argmax(axis=-1)
    
    return model, train_history, pre_probability

# %% [markdown]
# ### 6. Evaluation

# %% [markdown]
# #### 6.1 Subsetting training

# %%
CNN_c_model, CNN_c_history, CNN_c_pred = CNN_C(c_X1_train, c_X2_train, c_X1_test, 
                                               c_X2_test, y_train_c, y_test_c, 
                                               loss = jsd_custom_loss)
# Out:
# WARNING:tensorflow:From C:\Users\doudi\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 150)          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 150, 300)     5866800     input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150, 2)       1202        embedding_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 2)            0
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 37, 2)        0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          768         input_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 74)           0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 74)           0           flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          32896       dropout_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 202)          0           dropout_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 10)           2030        concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 4)            44          dense_3[0][0]
# ==================================================================================================
# Total params: 5,903,740
# Trainable params: 5,903,740
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From C:\Users\doudi\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\doudi\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 6800 samples, validate on 1700 samples
# Epoch 1/100
#  - 9s - loss: 0.0876 - accuracy: 0.8301 - val_loss: 0.0438 - val_accuracy: 0.8747
# Epoch 2/100
#  - 1s - loss: 0.0447 - accuracy: 0.8524 - val_loss: 0.0435 - val_accuracy: 0.8741
# Epoch 3/100
#  - 1s - loss: 0.0427 - accuracy: 0.8528 - val_loss: 0.0392 - val_accuracy: 0.8747
# Epoch 4/100
#  - 1s - loss: 0.0412 - accuracy: 0.8525 - val_loss: 0.0386 - val_accuracy: 0.8747
# Epoch 5/100
#  - 1s - loss: 0.0387 - accuracy: 0.8525 - val_loss: 0.0381 - val_accuracy: 0.8747
# Epoch 6/100
#  - 1s - loss: 0.0367 - accuracy: 0.8532 - val_loss: 0.0386 - val_accuracy: 0.8729
# Epoch 7/100
#  - 1s - loss: 0.0355 - accuracy: 0.8565 - val_loss: 0.0393 - val_accuracy: 0.8735
# Epoch 8/100
#  - 1s - loss: 0.0343 - accuracy: 0.8588 - val_loss: 0.0398 - val_accuracy: 0.8747
# Epoch 9/100
#  - 1s - loss: 0.0336 - accuracy: 0.8606 - val_loss: 0.0392 - val_accuracy: 0.8741
# Epoch 10/100
#  - 1s - loss: 0.0328 - accuracy: 0.8668 - val_loss: 0.0382 - val_accuracy: 0.8718
# Epoch 11/100
#  - 1s - loss: 0.0322 - accuracy: 0.8718 - val_loss: 0.0384 - val_accuracy: 0.8712
# Epoch 12/100
#  - 1s - loss: 0.0315 - accuracy: 0.8699 - val_loss: 0.0374 - val_accuracy: 0.8735
# Epoch 13/100
#  - 1s - loss: 0.0310 - accuracy: 0.8725 - val_loss: 0.0377 - val_accuracy: 0.8712
# Epoch 14/100
#  - 1s - loss: 0.0304 - accuracy: 0.8754 - val_loss: 0.0366 - val_accuracy: 0.8747
# Epoch 15/100
#  - 1s - loss: 0.0297 - accuracy: 0.8757 - val_loss: 0.0364 - val_accuracy: 0.8735
# Epoch 16/100
#  - 1s - loss: 0.0293 - accuracy: 0.8768 - val_loss: 0.0373 - val_accuracy: 0.8688
# Epoch 17/100
#  - 1s - loss: 0.0287 - accuracy: 0.8815 - val_loss: 0.0375 - val_accuracy: 0.8724
# Epoch 18/100
#  - 1s - loss: 0.0286 - accuracy: 0.8784 - val_loss: 0.0366 - val_accuracy: 0.8735
# Epoch 19/100
#  - 1s - loss: 0.0284 - accuracy: 0.8784 - val_loss: 0.0373 - val_accuracy: 0.8735
# Epoch 20/100
#  - 1s - loss: 0.0275 - accuracy: 0.8831 - val_loss: 0.0376 - val_accuracy: 0.8706
# Epoch 21/100
#  - 1s - loss: 0.0274 - accuracy: 0.8828 - val_loss: 0.0382 - val_accuracy: 0.8676
# Epoch 22/100
#  - 1s - loss: 0.0270 - accuracy: 0.8829 - val_loss: 0.0375 - val_accuracy: 0.8724
# Epoch 23/100
#  - 1s - loss: 0.0270 - accuracy: 0.8804 - val_loss: 0.0373 - val_accuracy: 0.8694
# Epoch 24/100
#  - 1s - loss: 0.0268 - accuracy: 0.8799 - val_loss: 0.0366 - val_accuracy: 0.8747
# Epoch 25/100
#  - 1s - loss: 0.0263 - accuracy: 0.8828 - val_loss: 0.0372 - val_accuracy: 0.8718
# Epoch 26/100
#  - 1s - loss: 0.0262 - accuracy: 0.8834 - val_loss: 0.0380 - val_accuracy: 0.8665
# Epoch 27/100
#  - 1s - loss: 0.0262 - accuracy: 0.8815 - val_loss: 0.0371 - val_accuracy: 0.8712
# Epoch 28/100
#  - 1s - loss: 0.0261 - accuracy: 0.8788 - val_loss: 0.0371 - val_accuracy: 0.8724
# Epoch 29/100
#  - 1s - loss: 0.0256 - accuracy: 0.8834 - val_loss: 0.0371 - val_accuracy: 0.8712
# Epoch 30/100
#  - 1s - loss: 0.0255 - accuracy: 0.8844 - val_loss: 0.0371 - val_accuracy: 0.8718
# Epoch 31/100
#  - 1s - loss: 0.0251 - accuracy: 0.8843 - val_loss: 0.0373 - val_accuracy: 0.8694
# Epoch 32/100
#  - 1s - loss: 0.0251 - accuracy: 0.8840 - val_loss: 0.0372 - val_accuracy: 0.8729
# Epoch 33/100
#  - 1s - loss: 0.0247 - accuracy: 0.8828 - val_loss: 0.0369 - val_accuracy: 0.8712
# Epoch 34/100
#  - 1s - loss: 0.0248 - accuracy: 0.8846 - val_loss: 0.0373 - val_accuracy: 0.8700
# Epoch 35/100
#  - 1s - loss: 0.0243 - accuracy: 0.8866 - val_loss: 0.0376 - val_accuracy: 0.8706
# Epoch 36/100
#  - 1s - loss: 0.0241 - accuracy: 0.8869 - val_loss: 0.0373 - val_accuracy: 0.8718
# Epoch 37/100
#  - 1s - loss: 0.0242 - accuracy: 0.8851 - val_loss: 0.0372 - val_accuracy: 0.8706
# Epoch 38/100
#  - 1s - loss: 0.0239 - accuracy: 0.8872 - val_loss: 0.0371 - val_accuracy: 0.8724
# Epoch 39/100
#  - 1s - loss: 0.0238 - accuracy: 0.8862 - val_loss: 0.0372 - val_accuracy: 0.8718
# Epoch 40/100
#  - 1s - loss: 0.0238 - accuracy: 0.8860 - val_loss: 0.0381 - val_accuracy: 0.8712
# Epoch 41/100
#  - 1s - loss: 0.0239 - accuracy: 0.8882 - val_loss: 0.0378 - val_accuracy: 0.8694
# Epoch 42/100
#  - 1s - loss: 0.0237 - accuracy: 0.8851 - val_loss: 0.0377 - val_accuracy: 0.8688
# Epoch 43/100
#  - 1s - loss: 0.0233 - accuracy: 0.8894 - val_loss: 0.0378 - val_accuracy: 0.8688
# Epoch 44/100
#  - 1s - loss: 0.0229 - accuracy: 0.8885 - val_loss: 0.0378 - val_accuracy: 0.8724
# Epoch 45/100
#  - 1s - loss: 0.0233 - accuracy: 0.8868 - val_loss: 0.0378 - val_accuracy: 0.8688
# Epoch 46/100
#  - 1s - loss: 0.0230 - accuracy: 0.8913 - val_loss: 0.0375 - val_accuracy: 0.8706
# Epoch 47/100
#  - 1s - loss: 0.0232 - accuracy: 0.8903 - val_loss: 0.0377 - val_accuracy: 0.8729
# Epoch 48/100
#  - 1s - loss: 0.0235 - accuracy: 0.8847 - val_loss: 0.0378 - val_accuracy: 0.8700
# Epoch 49/100
#  - 1s - loss: 0.0231 - accuracy: 0.8869 - val_loss: 0.0378 - val_accuracy: 0.8688
# Epoch 50/100
#  - 1s - loss: 0.0226 - accuracy: 0.8915 - val_loss: 0.0382 - val_accuracy: 0.8671
# Epoch 51/100
#  - 1s - loss: 0.0229 - accuracy: 0.8862 - val_loss: 0.0381 - val_accuracy: 0.8676
# Epoch 52/100
#  - 1s - loss: 0.0228 - accuracy: 0.8907 - val_loss: 0.0382 - val_accuracy: 0.8659
# Epoch 53/100
#  - 1s - loss: 0.0227 - accuracy: 0.8897 - val_loss: 0.0380 - val_accuracy: 0.8688
# Epoch 54/100
#  - 1s - loss: 0.0229 - accuracy: 0.8890 - val_loss: 0.0384 - val_accuracy: 0.8653
# Epoch 55/100
#  - 1s - loss: 0.0227 - accuracy: 0.8866 - val_loss: 0.0378 - val_accuracy: 0.8694
# Epoch 56/100
#  - 1s - loss: 0.0224 - accuracy: 0.8884 - val_loss: 0.0384 - val_accuracy: 0.8671
# Epoch 57/100
#  - 1s - loss: 0.0227 - accuracy: 0.8919 - val_loss: 0.0380 - val_accuracy: 0.8724
# Epoch 58/100
#  - 1s - loss: 0.0226 - accuracy: 0.8893 - val_loss: 0.0383 - val_accuracy: 0.8688
# Epoch 59/100
#  - 1s - loss: 0.0224 - accuracy: 0.8893 - val_loss: 0.0384 - val_accuracy: 0.8706
# Epoch 60/100
#  - 1s - loss: 0.0223 - accuracy: 0.8884 - val_loss: 0.0384 - val_accuracy: 0.8688
# Epoch 61/100
#  - 1s - loss: 0.0222 - accuracy: 0.8876 - val_loss: 0.0386 - val_accuracy: 0.8688
# Epoch 62/100
#  - 1s - loss: 0.0224 - accuracy: 0.8888 - val_loss: 0.0387 - val_accuracy: 0.8676
# Epoch 63/100
#  - 1s - loss: 0.0221 - accuracy: 0.8890 - val_loss: 0.0381 - val_accuracy: 0.8700
# Epoch 64/100
#  - 1s - loss: 0.0220 - accuracy: 0.8906 - val_loss: 0.0385 - val_accuracy: 0.8706
# Epoch 65/100
#  - 1s - loss: 0.0221 - accuracy: 0.8910 - val_loss: 0.0388 - val_accuracy: 0.8676
# Epoch 66/100
#  - 1s - loss: 0.0218 - accuracy: 0.8900 - val_loss: 0.0384 - val_accuracy: 0.8665
# Epoch 67/100
#  - 1s - loss: 0.0219 - accuracy: 0.8909 - val_loss: 0.0386 - val_accuracy: 0.8641
# Epoch 68/100
#  - 1s - loss: 0.0219 - accuracy: 0.8875 - val_loss: 0.0385 - val_accuracy: 0.8659
# Epoch 69/100
#  - 1s - loss: 0.0221 - accuracy: 0.8887 - val_loss: 0.0388 - val_accuracy: 0.8671
# Epoch 70/100
#  - 1s - loss: 0.0222 - accuracy: 0.8934 - val_loss: 0.0386 - val_accuracy: 0.8694
# Epoch 71/100
#  - 1s - loss: 0.0218 - accuracy: 0.8882 - val_loss: 0.0387 - val_accuracy: 0.8676
# Epoch 72/100
#  - 1s - loss: 0.0218 - accuracy: 0.8888 - val_loss: 0.0391 - val_accuracy: 0.8659
# Epoch 73/100
#  - 1s - loss: 0.0221 - accuracy: 0.8900 - val_loss: 0.0384 - val_accuracy: 0.8676
# Epoch 74/100
#  - 1s - loss: 0.0221 - accuracy: 0.8868 - val_loss: 0.0387 - val_accuracy: 0.8659
# Epoch 75/100
#  - 1s - loss: 0.0219 - accuracy: 0.8903 - val_loss: 0.0384 - val_accuracy: 0.8682
# Epoch 76/100
#  - 1s - loss: 0.0216 - accuracy: 0.8868 - val_loss: 0.0391 - val_accuracy: 0.8647
# Epoch 77/100
#  - 1s - loss: 0.0214 - accuracy: 0.8910 - val_loss: 0.0389 - val_accuracy: 0.8659
# Epoch 78/100
#  - 1s - loss: 0.0221 - accuracy: 0.8901 - val_loss: 0.0390 - val_accuracy: 0.8665
# Epoch 79/100
#  - 1s - loss: 0.0218 - accuracy: 0.8894 - val_loss: 0.0390 - val_accuracy: 0.8671
# Epoch 80/100
#  - 1s - loss: 0.0219 - accuracy: 0.8876 - val_loss: 0.0388 - val_accuracy: 0.8700
# Epoch 81/100
#  - 1s - loss: 0.0219 - accuracy: 0.8878 - val_loss: 0.0394 - val_accuracy: 0.8624
# Epoch 82/100
#  - 1s - loss: 0.0218 - accuracy: 0.8874 - val_loss: 0.0385 - val_accuracy: 0.8706
# Epoch 83/100
#  - 1s - loss: 0.0216 - accuracy: 0.8910 - val_loss: 0.0389 - val_accuracy: 0.8653
# Epoch 84/100
#  - 1s - loss: 0.0214 - accuracy: 0.8910 - val_loss: 0.0391 - val_accuracy: 0.8653
# Epoch 85/100
#  - 1s - loss: 0.0215 - accuracy: 0.8926 - val_loss: 0.0392 - val_accuracy: 0.8647
# Epoch 86/100
#  - 1s - loss: 0.0214 - accuracy: 0.8919 - val_loss: 0.0391 - val_accuracy: 0.8647
# Epoch 87/100
#  - 1s - loss: 0.0213 - accuracy: 0.8931 - val_loss: 0.0398 - val_accuracy: 0.8629
# Epoch 88/100
#  - 1s - loss: 0.0214 - accuracy: 0.8887 - val_loss: 0.0393 - val_accuracy: 0.8682
# Epoch 89/100
#  - 1s - loss: 0.0212 - accuracy: 0.8894 - val_loss: 0.0394 - val_accuracy: 0.8641
# Epoch 90/100
#  - 1s - loss: 0.0214 - accuracy: 0.8912 - val_loss: 0.0391 - val_accuracy: 0.8676
# Epoch 91/100
#  - 1s - loss: 0.0213 - accuracy: 0.8900 - val_loss: 0.0393 - val_accuracy: 0.8647
# Epoch 92/100
#  - 1s - loss: 0.0214 - accuracy: 0.8904 - val_loss: 0.0398 - val_accuracy: 0.8653
# Epoch 93/100
#  - 1s - loss: 0.0218 - accuracy: 0.8907 - val_loss: 0.0397 - val_accuracy: 0.8629
# Epoch 94/100
#  - 1s - loss: 0.0216 - accuracy: 0.8918 - val_loss: 0.0394 - val_accuracy: 0.8659
# Epoch 95/100
#  - 1s - loss: 0.0215 - accuracy: 0.8915 - val_loss: 0.0391 - val_accuracy: 0.8694
# Epoch 96/100
#  - 1s - loss: 0.0212 - accuracy: 0.8913 - val_loss: 0.0395 - val_accuracy: 0.8659
# Epoch 97/100
#  - 1s - loss: 0.0214 - accuracy: 0.8921 - val_loss: 0.0395 - val_accuracy: 0.8635
# Epoch 98/100
#  - 1s - loss: 0.0215 - accuracy: 0.8918 - val_loss: 0.0393 - val_accuracy: 0.8676
# Epoch 99/100
#  - 1s - loss: 0.0212 - accuracy: 0.8921 - val_loss: 0.0398 - val_accuracy: 0.8635
# Epoch 100/100
#  - 1s - loss: 0.0212 - accuracy: 0.8935 - val_loss: 0.0396 - val_accuracy: 0.8641
# 975/975 [==============================] - 0s 124us/step
# Test Score: 0.03948532971625145
# Test Accuracy: 0.854358971118927

# %%
CNN_h_model, CNN_h_history, CNN_h_pred = CNN_H(h_X1_train, h_X2_train, h_X1_test, 
                                               h_X2_test, y_train_h, y_test_h, 
                                               loss = jsd_custom_loss)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 150)          0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 150, 300)     1982100     input_3[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 150, 2)       1202        embedding_2[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 2)            0
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 37, 2)        0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 256)          768         input_4[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 74)           0           max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 256)          0           dense_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 74)           0           flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          32896       dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 202)          0           dropout_3[0][0]
#                                                                  dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 10)           2030        concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 3)            33          dense_7[0][0]
# ==================================================================================================
# Total params: 2,019,029
# Trainable params: 2,019,029
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Train on 5520 samples, validate on 1380 samples
# Epoch 1/100
#  - 1s - loss: 0.0465 - accuracy: 0.8116 - val_loss: 0.0416 - val_accuracy: 0.8217
# Epoch 2/100
#  - 1s - loss: 0.0393 - accuracy: 0.8152 - val_loss: 0.0354 - val_accuracy: 0.8442
# Epoch 3/100
#  - 1s - loss: 0.0329 - accuracy: 0.8163 - val_loss: 0.0305 - val_accuracy: 0.8428
# Epoch 4/100
#  - 1s - loss: 0.0299 - accuracy: 0.8199 - val_loss: 0.0290 - val_accuracy: 0.8406
# Epoch 5/100
#  - 1s - loss: 0.0280 - accuracy: 0.8255 - val_loss: 0.0287 - val_accuracy: 0.8341
# Epoch 6/100
#  - 1s - loss: 0.0270 - accuracy: 0.8250 - val_loss: 0.0282 - val_accuracy: 0.8362
# Epoch 7/100
#  - 1s - loss: 0.0259 - accuracy: 0.8299 - val_loss: 0.0282 - val_accuracy: 0.8587
# Epoch 8/100
#  - 1s - loss: 0.0251 - accuracy: 0.8339 - val_loss: 0.0281 - val_accuracy: 0.8493
# Epoch 9/100
#  - 1s - loss: 0.0242 - accuracy: 0.8346 - val_loss: 0.0275 - val_accuracy: 0.8565
# Epoch 10/100
#  - 1s - loss: 0.0239 - accuracy: 0.8397 - val_loss: 0.0287 - val_accuracy: 0.8514
# Epoch 11/100
#  - 1s - loss: 0.0234 - accuracy: 0.8380 - val_loss: 0.0281 - val_accuracy: 0.8558
# Epoch 12/100
#  - 1s - loss: 0.0227 - accuracy: 0.8466 - val_loss: 0.0274 - val_accuracy: 0.8587
# Epoch 13/100
#  - 1s - loss: 0.0228 - accuracy: 0.8406 - val_loss: 0.0277 - val_accuracy: 0.8543
# Epoch 14/100
#  - 1s - loss: 0.0221 - accuracy: 0.8446 - val_loss: 0.0268 - val_accuracy: 0.8659
# Epoch 15/100
#  - 1s - loss: 0.0221 - accuracy: 0.8536 - val_loss: 0.0274 - val_accuracy: 0.8522
# Epoch 16/100
#  - 1s - loss: 0.0218 - accuracy: 0.8478 - val_loss: 0.0267 - val_accuracy: 0.8601
# Epoch 17/100
#  - 1s - loss: 0.0215 - accuracy: 0.8475 - val_loss: 0.0268 - val_accuracy: 0.8674
# Epoch 18/100
#  - 1s - loss: 0.0214 - accuracy: 0.8491 - val_loss: 0.0268 - val_accuracy: 0.8623
# Epoch 19/100
#  - 1s - loss: 0.0205 - accuracy: 0.8612 - val_loss: 0.0267 - val_accuracy: 0.8638
# Epoch 20/100
#  - 1s - loss: 0.0210 - accuracy: 0.8514 - val_loss: 0.0266 - val_accuracy: 0.8674
# Epoch 21/100
#  - 1s - loss: 0.0207 - accuracy: 0.8518 - val_loss: 0.0270 - val_accuracy: 0.8601
# Epoch 22/100
#  - 1s - loss: 0.0205 - accuracy: 0.8603 - val_loss: 0.0267 - val_accuracy: 0.8638
# Epoch 23/100
#  - 1s - loss: 0.0201 - accuracy: 0.8596 - val_loss: 0.0267 - val_accuracy: 0.8696
# Epoch 24/100
#  - 1s - loss: 0.0204 - accuracy: 0.8594 - val_loss: 0.0271 - val_accuracy: 0.8674
# Epoch 25/100
#  - 1s - loss: 0.0199 - accuracy: 0.8616 - val_loss: 0.0269 - val_accuracy: 0.8659
# Epoch 26/100
#  - 1s - loss: 0.0199 - accuracy: 0.8672 - val_loss: 0.0270 - val_accuracy: 0.8594
# Epoch 27/100
#  - 1s - loss: 0.0202 - accuracy: 0.8572 - val_loss: 0.0269 - val_accuracy: 0.8652
# Epoch 28/100
# Epoch 53/100
#  - 1s - loss: 0.0181 - accuracy: 0.8759 - val_loss: 0.0276 - val_accuracy: 0.8514
# Epoch 54/100
#  - 1s - loss: 0.0183 - accuracy: 0.8663 - val_loss: 0.0275 - val_accuracy: 0.8572
# Epoch 55/100
#  - 1s - loss: 0.0181 - accuracy: 0.8730 - val_loss: 0.0277 - val_accuracy: 0.8522
# Epoch 56/100
#  - 1s - loss: 0.0174 - accuracy: 0.8774 - val_loss: 0.0277 - val_accuracy: 0.8638
# Epoch 57/100
#  - 1s - loss: 0.0176 - accuracy: 0.8801 - val_loss: 0.0278 - val_accuracy: 0.8543
# Epoch 58/100
#  - 1s - loss: 0.0185 - accuracy: 0.8737 - val_loss: 0.0278 - val_accuracy: 0.8449
# Epoch 59/100
#  - 1s - loss: 0.0180 - accuracy: 0.8726 - val_loss: 0.0281 - val_accuracy: 0.8435
# Epoch 60/100
#  - 1s - loss: 0.0180 - accuracy: 0.8717 - val_loss: 0.0280 - val_accuracy: 0.8536
# Epoch 61/100
#  - 1s - loss: 0.0176 - accuracy: 0.8761 - val_loss: 0.0282 - val_accuracy: 0.8543
# Epoch 62/100
#  - 1s - loss: 0.0179 - accuracy: 0.8759 - val_loss: 0.0282 - val_accuracy: 0.8565
# Epoch 63/100
#  - 1s - loss: 0.0176 - accuracy: 0.8750 - val_loss: 0.0285 - val_accuracy: 0.8529
# Epoch 64/100
#  - 1s - loss: 0.0177 - accuracy: 0.8732 - val_loss: 0.0282 - val_accuracy: 0.8500
# Epoch 65/100
#  - 1s - loss: 0.0178 - accuracy: 0.8783 - val_loss: 0.0280 - val_accuracy: 0.8464
# Epoch 66/100
#  - 1s - loss: 0.0177 - accuracy: 0.8714 - val_loss: 0.0283 - val_accuracy: 0.8551
# Epoch 67/100
#  - 1s - loss: 0.0177 - accuracy: 0.8795 - val_loss: 0.0284 - val_accuracy: 0.8493
# Epoch 68/100
#  - 1s - loss: 0.0180 - accuracy: 0.8743 - val_loss: 0.0283 - val_accuracy: 0.8558
# Epoch 69/100
#  - 1s - loss: 0.0179 - accuracy: 0.8819 - val_loss: 0.0281 - val_accuracy: 0.8543
# Epoch 70/100
#  - 1s - loss: 0.0173 - accuracy: 0.8799 - val_loss: 0.0282 - val_accuracy: 0.8587
# Epoch 71/100
#  - 1s - loss: 0.0174 - accuracy: 0.8716 - val_loss: 0.0277 - val_accuracy: 0.8572
# Epoch 72/100
#  - 1s - loss: 0.0172 - accuracy: 0.8779 - val_loss: 0.0279 - val_accuracy: 0.8522
# Epoch 73/100
#  - 1s - loss: 0.0175 - accuracy: 0.8763 - val_loss: 0.0284 - val_accuracy: 0.8500
# Epoch 74/100
#  - 1s - loss: 0.0174 - accuracy: 0.8745 - val_loss: 0.0281 - val_accuracy: 0.8514
# Epoch 75/100
#  - 1s - loss: 0.0175 - accuracy: 0.8804 - val_loss: 0.0283 - val_accuracy: 0.8587
# Epoch 76/100
#  - 1s - loss: 0.0173 - accuracy: 0.8797 - val_loss: 0.0281 - val_accuracy: 0.8652
# Epoch 77/100
#  - 1s - loss: 0.0180 - accuracy: 0.8739 - val_loss: 0.0284 - val_accuracy: 0.8507
# Epoch 78/100
#  - 1s - loss: 0.0171 - accuracy: 0.8804 - val_loss: 0.0280 - val_accuracy: 0.8478
# Epoch 79/100
#  - 1s - loss: 0.0174 - accuracy: 0.8795 - val_loss: 0.0285 - val_accuracy: 0.8522
# Epoch 80/100
#  - 1s - loss: 0.0175 - accuracy: 0.8803 - val_loss: 0.0282 - val_accuracy: 0.8493
# Epoch 81/100
#  - 1s - loss: 0.0172 - accuracy: 0.8833 - val_loss: 0.0285 - val_accuracy: 0.8522
# Epoch 82/100
#  - 1s - loss: 0.0172 - accuracy: 0.8788 - val_loss: 0.0286 - val_accuracy: 0.8486
# Epoch 83/100
#  - 1s - loss: 0.0174 - accuracy: 0.8808 - val_loss: 0.0282 - val_accuracy: 0.8529
# Epoch 84/100
#  - 1s - loss: 0.0170 - accuracy: 0.8797 - val_loss: 0.0285 - val_accuracy: 0.8616
# Epoch 85/100
#  - 1s - loss: 0.0173 - accuracy: 0.8804 - val_loss: 0.0282 - val_accuracy: 0.8551
# Epoch 86/100
#  - 1s - loss: 0.0174 - accuracy: 0.8734 - val_loss: 0.0282 - val_accuracy: 0.8500
# Epoch 87/100
#  - 1s - loss: 0.0173 - accuracy: 0.8835 - val_loss: 0.0278 - val_accuracy: 0.8529
# Epoch 88/100
#  - 1s - loss: 0.0168 - accuracy: 0.8879 - val_loss: 0.0280 - val_accuracy: 0.8623
# Epoch 89/100
#  - 1s - loss: 0.0173 - accuracy: 0.8746 - val_loss: 0.0281 - val_accuracy: 0.8529
# Epoch 90/100
#  - 1s - loss: 0.0170 - accuracy: 0.8790 - val_loss: 0.0284 - val_accuracy: 0.8536
# Epoch 91/100
#  - 1s - loss: 0.0174 - accuracy: 0.8830 - val_loss: 0.0285 - val_accuracy: 0.8594
# Epoch 92/100
#  - 1s - loss: 0.0170 - accuracy: 0.8806 - val_loss: 0.0283 - val_accuracy: 0.8587
# Epoch 93/100
#  - 1s - loss: 0.0173 - accuracy: 0.8812 - val_loss: 0.0282 - val_accuracy: 0.8587
# Epoch 94/100
#  - 1s - loss: 0.0175 - accuracy: 0.8815 - val_loss: 0.0285 - val_accuracy: 0.8580
# Epoch 95/100
#  - 1s - loss: 0.0172 - accuracy: 0.8775 - val_loss: 0.0285 - val_accuracy: 0.8623
# Epoch 96/100
#  - 1s - loss: 0.0175 - accuracy: 0.8817 - val_loss: 0.0286 - val_accuracy: 0.8601
# Epoch 97/100
#  - 1s - loss: 0.0172 - accuracy: 0.8815 - val_loss: 0.0282 - val_accuracy: 0.8572
# Epoch 98/100
#  - 1s - loss: 0.0169 - accuracy: 0.8817 - val_loss: 0.0281 - val_accuracy: 0.8558
# Epoch 99/100
#  - 1s - loss: 0.0168 - accuracy: 0.8846 - val_loss: 0.0286 - val_accuracy: 0.8558
# Epoch 100/100
#  - 1s - loss: 0.0169 - accuracy: 0.8832 - val_loss: 0.0283 - val_accuracy: 0.8522
# 780/780 [==============================] - 0s 127us/step
# Test Score: 0.0284992195188235
# Test Accuracy: 0.8602564334869385

# %%
lstm_c_model, lstm_c_history, lstm_c_pred = lstm_C(c_X1_train, c_X2_train, c_X1_test, 
                                               c_X2_test, y_train_c, y_test_c, 
                                               loss = jsd_custom_loss)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            (None, 150)          0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 150, 32)      640000      input_7[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 150, 32)      0           embedding_4[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 16)           3136        dropout_8[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 256)          4352        lstm_2[0][0]
# __________________________________________________________________________________________________
# input_8 (InputLayer)            (None, 2)            0
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 256)          0           dense_16[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 256)          768         input_8[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 128)          32896       dropout_9[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 256)          0           dense_19[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 4)            516         dense_17[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 128)          32896       dropout_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 132)          0           dense_18[0][0]
#                                                                  dense_20[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 10)           1330        concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 4)            44          dense_21[0][0]
# ==================================================================================================
# Total params: 715,938
# Trainable params: 715,938
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Train on 6800 samples, validate on 1700 samples
# Epoch 1/100
#  - 14s - loss: 0.0624 - accuracy: 0.7985 - val_loss: 0.0440 - val_accuracy: 0.8747
# Epoch 2/100
#  - 14s - loss: 0.0457 - accuracy: 0.8526 - val_loss: 0.0425 - val_accuracy: 0.8747
# Epoch 3/100
#  - 14s - loss: 0.0441 - accuracy: 0.8526 - val_loss: 0.0400 - val_accuracy: 0.8747
# Epoch 4/100
#  - 14s - loss: 0.0407 - accuracy: 0.8516 - val_loss: 0.0385 - val_accuracy: 0.8747
# Epoch 5/100
#  - 14s - loss: 0.0381 - accuracy: 0.8528 - val_loss: 0.0383 - val_accuracy: 0.8624
# Epoch 6/100
#  - 14s - loss: 0.0362 - accuracy: 0.8525 - val_loss: 0.0372 - val_accuracy: 0.8747
# Epoch 7/100
#  - 14s - loss: 0.0343 - accuracy: 0.8532 - val_loss: 0.0384 - val_accuracy: 0.8706
# Epoch 8/100
#  - 14s - loss: 0.0327 - accuracy: 0.8613 - val_loss: 0.0375 - val_accuracy: 0.8800
# Epoch 9/100
#  - 14s - loss: 0.0310 - accuracy: 0.8651 - val_loss: 0.0366 - val_accuracy: 0.8753
# Epoch 10/100
#  - 14s - loss: 0.0293 - accuracy: 0.8866 - val_loss: 0.0371 - val_accuracy: 0.8571
# Epoch 11/100
#  - 14s - loss: 0.0278 - accuracy: 0.8882 - val_loss: 0.0354 - val_accuracy: 0.8682
# Epoch 12/100
#  - 14s - loss: 0.0264 - accuracy: 0.8956 - val_loss: 0.0347 - val_accuracy: 0.8729
# Epoch 13/100
#  - 14s - loss: 0.0253 - accuracy: 0.8903 - val_loss: 0.0350 - val_accuracy: 0.8518
# Epoch 14/100
#  - 14s - loss: 0.0235 - accuracy: 0.8900 - val_loss: 0.0331 - val_accuracy: 0.8665
# Epoch 15/100
#  - 14s - loss: 0.0220 - accuracy: 0.8840 - val_loss: 0.0324 - val_accuracy: 0.8824
# Epoch 16/100
#  - 14s - loss: 0.0206 - accuracy: 0.8818 - val_loss: 0.0326 - val_accuracy: 0.8647
# Epoch 17/100
#  - 14s - loss: 0.0195 - accuracy: 0.8932 - val_loss: 0.0329 - val_accuracy: 0.8765
# Epoch 18/100
#  - 14s - loss: 0.0189 - accuracy: 0.9034 - val_loss: 0.0331 - val_accuracy: 0.8812
# Epoch 19/100
#  - 14s - loss: 0.0182 - accuracy: 0.9072 - val_loss: 0.0328 - val_accuracy: 0.8512
# Epoch 20/100
#  - 14s - loss: 0.0180 - accuracy: 0.9190 - val_loss: 0.0322 - val_accuracy: 0.8735
# Epoch 21/100
#  - 14s - loss: 0.0174 - accuracy: 0.9190 - val_loss: 0.0325 - val_accuracy: 0.8629
# Epoch 22/100
#  - 13s - loss: 0.0169 - accuracy: 0.9221 - val_loss: 0.0319 - val_accuracy: 0.8641
# Epoch 23/100
#  - 14s - loss: 0.0164 - accuracy: 0.9296 - val_loss: 0.0314 - val_accuracy: 0.8694
# Epoch 24/100
#  - 13s - loss: 0.0163 - accuracy: 0.9290 - val_loss: 0.0320 - val_accuracy: 0.8594
# Epoch 25/100
#  - 14s - loss: 0.0159 - accuracy: 0.9306 - val_loss: 0.0321 - val_accuracy: 0.8641
# Epoch 26/100
#  - 14s - loss: 0.0157 - accuracy: 0.9328 - val_loss: 0.0313 - val_accuracy: 0.8682
# Epoch 27/100
#  - 13s - loss: 0.0154 - accuracy: 0.9304 - val_loss: 0.0314 - val_accuracy: 0.8665
# Epoch 28/100
#  - 13s - loss: 0.0151 - accuracy: 0.9316 - val_loss: 0.0316 - val_accuracy: 0.8600
# Epoch 29/100
#  - 13s - loss: 0.0151 - accuracy: 0.9324 - val_loss: 0.0314 - val_accuracy: 0.8735
# Epoch 30/100
#  - 13s - loss: 0.0147 - accuracy: 0.9388 - val_loss: 0.0313 - val_accuracy: 0.8724
# Epoch 31/100
#  - 14s - loss: 0.0144 - accuracy: 0.9378 - val_loss: 0.0315 - val_accuracy: 0.8665
# Epoch 32/100
#  - 13s - loss: 0.0143 - accuracy: 0.9385 - val_loss: 0.0317 - val_accuracy: 0.8659
# Epoch 33/100
#  - 13s - loss: 0.0141 - accuracy: 0.9374 - val_loss: 0.0317 - val_accuracy: 0.8806
# Epoch 34/100
#  - 14s - loss: 0.0142 - accuracy: 0.9363 - val_loss: 0.0313 - val_accuracy: 0.8753
# Epoch 35/100
#  - 13s - loss: 0.0139 - accuracy: 0.9379 - val_loss: 0.0313 - val_accuracy: 0.8771
# Epoch 36/100
#  - 14s - loss: 0.0138 - accuracy: 0.9397 - val_loss: 0.0311 - val_accuracy: 0.8653
# Epoch 37/100
#  - 14s - loss: 0.0135 - accuracy: 0.9396 - val_loss: 0.0318 - val_accuracy: 0.8712
# Epoch 38/100
#  - 14s - loss: 0.0133 - accuracy: 0.9376 - val_loss: 0.0312 - val_accuracy: 0.8688
# Epoch 39/100
#  - 14s - loss: 0.0133 - accuracy: 0.9403 - val_loss: 0.0308 - val_accuracy: 0.8694
# Epoch 40/100
#  - 14s - loss: 0.0132 - accuracy: 0.9418 - val_loss: 0.0307 - val_accuracy: 0.8735
# Epoch 41/100
#  - 14s - loss: 0.0130 - accuracy: 0.9410 - val_loss: 0.0316 - val_accuracy: 0.8718
# Epoch 42/100
#  - 14s - loss: 0.0128 - accuracy: 0.9421 - val_loss: 0.0309 - val_accuracy: 0.8747
# Epoch 43/100
#  - 14s - loss: 0.0128 - accuracy: 0.9424 - val_loss: 0.0311 - val_accuracy: 0.8735
# Epoch 44/100
#  - 14s - loss: 0.0127 - accuracy: 0.9419 - val_loss: 0.0312 - val_accuracy: 0.8712
# Epoch 45/100
#  - 13s - loss: 0.0127 - accuracy: 0.9394 - val_loss: 0.0307 - val_accuracy: 0.8818
# Epoch 46/100
#  - 14s - loss: 0.0125 - accuracy: 0.9426 - val_loss: 0.0311 - val_accuracy: 0.8806
# Epoch 47/100
#  - 13s - loss: 0.0126 - accuracy: 0.9422 - val_loss: 0.0318 - val_accuracy: 0.8712
# Epoch 48/100
#  - 14s - loss: 0.0124 - accuracy: 0.9419 - val_loss: 0.0307 - val_accuracy: 0.8812
# Epoch 49/100
#  - 13s - loss: 0.0122 - accuracy: 0.9426 - val_loss: 0.0309 - val_accuracy: 0.8782
# Epoch 50/100
#  - 13s - loss: 0.0121 - accuracy: 0.9459 - val_loss: 0.0311 - val_accuracy: 0.8747
# Epoch 51/100
#  - 14s - loss: 0.0121 - accuracy: 0.9440 - val_loss: 0.0308 - val_accuracy: 0.8776
# Epoch 52/100
#  - 14s - loss: 0.0120 - accuracy: 0.9421 - val_loss: 0.0309 - val_accuracy: 0.8765
# Epoch 53/100
#  - 14s - loss: 0.0119 - accuracy: 0.9419 - val_loss: 0.0315 - val_accuracy: 0.8712
# Epoch 54/100
#  - 14s - loss: 0.0119 - accuracy: 0.9460 - val_loss: 0.0321 - val_accuracy: 0.8776
# Epoch 55/100
#  - 14s - loss: 0.0119 - accuracy: 0.9468 - val_loss: 0.0313 - val_accuracy: 0.8847
# Epoch 56/100
#  - 14s - loss: 0.0115 - accuracy: 0.9415 - val_loss: 0.0308 - val_accuracy: 0.8700
# Epoch 57/100
#  - 14s - loss: 0.0115 - accuracy: 0.9449 - val_loss: 0.0311 - val_accuracy: 0.8718
# Epoch 58/100
#  - 14s - loss: 0.0113 - accuracy: 0.9469 - val_loss: 0.0311 - val_accuracy: 0.8806
# Epoch 59/100
#  - 14s - loss: 0.0111 - accuracy: 0.9469 - val_loss: 0.0312 - val_accuracy: 0.8800
# Epoch 60/100
#  - 14s - loss: 0.0109 - accuracy: 0.9440 - val_loss: 0.0311 - val_accuracy: 0.8818
# Epoch 61/100
#  - 14s - loss: 0.0109 - accuracy: 0.9466 - val_loss: 0.0312 - val_accuracy: 0.8788
# Epoch 62/100
#  - 14s - loss: 0.0107 - accuracy: 0.9485 - val_loss: 0.0313 - val_accuracy: 0.8753
# Epoch 63/100
#  - 14s - loss: 0.0106 - accuracy: 0.9460 - val_loss: 0.0320 - val_accuracy: 0.8694
# Epoch 64/100
#  - 14s - loss: 0.0107 - accuracy: 0.9409 - val_loss: 0.0317 - val_accuracy: 0.8724
# Epoch 65/100
#  - 14s - loss: 0.0105 - accuracy: 0.9475 - val_loss: 0.0315 - val_accuracy: 0.8794
# Epoch 66/100
#  - 14s - loss: 0.0103 - accuracy: 0.9463 - val_loss: 0.0318 - val_accuracy: 0.8735
# Epoch 67/100
#  - 14s - loss: 0.0103 - accuracy: 0.9481 - val_loss: 0.0321 - val_accuracy: 0.8718
# Epoch 68/100
#  - 14s - loss: 0.0102 - accuracy: 0.9454 - val_loss: 0.0321 - val_accuracy: 0.8724
# Epoch 69/100
#  - 14s - loss: 0.0101 - accuracy: 0.9463 - val_loss: 0.0321 - val_accuracy: 0.8753
# Epoch 70/100
#  - 14s - loss: 0.0100 - accuracy: 0.9475 - val_loss: 0.0314 - val_accuracy: 0.8912
# Epoch 71/100
#  - 14s - loss: 0.0100 - accuracy: 0.9466 - val_loss: 0.0321 - val_accuracy: 0.8753
# Epoch 72/100
#  - 14s - loss: 0.0099 - accuracy: 0.9503 - val_loss: 0.0320 - val_accuracy: 0.8847
# Epoch 73/100
#  - 14s - loss: 0.0098 - accuracy: 0.9476 - val_loss: 0.0322 - val_accuracy: 0.8794
# Epoch 74/100
#  - 14s - loss: 0.0098 - accuracy: 0.9447 - val_loss: 0.0316 - val_accuracy: 0.8876
# Epoch 75/100
#  - 14s - loss: 0.0097 - accuracy: 0.9524 - val_loss: 0.0326 - val_accuracy: 0.8694
# Epoch 76/100
#  - 13s - loss: 0.0096 - accuracy: 0.9509 - val_loss: 0.0319 - val_accuracy: 0.8806
# Epoch 77/100
#  - 14s - loss: 0.0096 - accuracy: 0.9475 - val_loss: 0.0326 - val_accuracy: 0.8818
# Epoch 78/100
#  - 14s - loss: 0.0097 - accuracy: 0.9494 - val_loss: 0.0321 - val_accuracy: 0.8800
# Epoch 79/100
#  - 14s - loss: 0.0096 - accuracy: 0.9479 - val_loss: 0.0318 - val_accuracy: 0.8824
# Epoch 80/100
#  - 14s - loss: 0.0094 - accuracy: 0.9460 - val_loss: 0.0330 - val_accuracy: 0.8835
# Epoch 81/100
#  - 14s - loss: 0.0094 - accuracy: 0.9499 - val_loss: 0.0327 - val_accuracy: 0.8741
# Epoch 82/100
#  - 14s - loss: 0.0093 - accuracy: 0.9472 - val_loss: 0.0320 - val_accuracy: 0.8765
# Epoch 83/100
#  - 14s - loss: 0.0093 - accuracy: 0.9482 - val_loss: 0.0322 - val_accuracy: 0.8759
# Epoch 84/100
#  - 14s - loss: 0.0093 - accuracy: 0.9490 - val_loss: 0.0319 - val_accuracy: 0.8824
# Epoch 85/100
#  - 13s - loss: 0.0092 - accuracy: 0.9488 - val_loss: 0.0327 - val_accuracy: 0.8812
# Epoch 86/100
#  - 14s - loss: 0.0091 - accuracy: 0.9497 - val_loss: 0.0320 - val_accuracy: 0.8888
# Epoch 87/100
#  - 14s - loss: 0.0092 - accuracy: 0.9475 - val_loss: 0.0319 - val_accuracy: 0.8853
# Epoch 88/100
#  - 13s - loss: 0.0092 - accuracy: 0.9484 - val_loss: 0.0318 - val_accuracy: 0.8865
# Epoch 89/100
#  - 13s - loss: 0.0091 - accuracy: 0.9494 - val_loss: 0.0320 - val_accuracy: 0.8759
# Epoch 90/100
#  - 14s - loss: 0.0091 - accuracy: 0.9509 - val_loss: 0.0326 - val_accuracy: 0.8841
# Epoch 91/100
#  - 13s - loss: 0.0090 - accuracy: 0.9500 - val_loss: 0.0326 - val_accuracy: 0.8782
# Epoch 92/100
#  - 13s - loss: 0.0090 - accuracy: 0.9497 - val_loss: 0.0324 - val_accuracy: 0.8771
# Epoch 93/100
#  - 14s - loss: 0.0091 - accuracy: 0.9481 - val_loss: 0.0325 - val_accuracy: 0.8694
# Epoch 94/100
#  - 14s - loss: 0.0090 - accuracy: 0.9509 - val_loss: 0.0323 - val_accuracy: 0.8776
# Epoch 95/100
#  - 14s - loss: 0.0090 - accuracy: 0.9510 - val_loss: 0.0326 - val_accuracy: 0.8782
# Epoch 96/100
#  - 14s - loss: 0.0089 - accuracy: 0.9500 - val_loss: 0.0326 - val_accuracy: 0.8806
# Epoch 97/100
#  - 14s - loss: 0.0090 - accuracy: 0.9515 - val_loss: 0.0319 - val_accuracy: 0.8765
# Epoch 98/100
#  - 13s - loss: 0.0089 - accuracy: 0.9522 - val_loss: 0.0330 - val_accuracy: 0.8888
# Epoch 99/100
#  - 13s - loss: 0.0090 - accuracy: 0.9524 - val_loss: 0.0325 - val_accuracy: 0.8735
# Epoch 100/100
#  - 14s - loss: 0.0089 - accuracy: 0.9525 - val_loss: 0.0324 - val_accuracy: 0.8776
# 975/975 [==============================] - 2s 2ms/step
# Test Score: 0.03334479789321239
# Test Accuracy: 0.8492307662963867

# %%
lstm_h_model, lstm_h_history, lstm_h_pred = lstm_H(h_X1_train, h_X2_train, h_X1_test, 
                                               h_X2_test, y_train_h, y_test_h,  
                                               loss = jsd_custom_loss)
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            (None, 150)          0
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 150, 32)      640000      input_9[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 150, 32)      0           embedding_5[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 16)           3136        dropout_11[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 256)          4352        lstm_3[0][0]
# __________________________________________________________________________________________________
# input_10 (InputLayer)           (None, 2)            0
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 256)          0           dense_23[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 256)          768         input_10[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 128)          32896       dropout_12[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 256)          0           dense_26[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 3)            387         dense_24[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 128)          32896       dropout_13[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 131)          0           dense_25[0][0]
#                                                                  dense_27[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 10)           1320        concatenate_5[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 3)            33          dense_28[0][0]
# ==================================================================================================
# Total params: 715,788
# Trainable params: 715,788
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Train on 5520 samples, validate on 1380 samples
# Epoch 1/100
#  - 12s - loss: 0.0486 - accuracy: 0.8101 - val_loss: 0.0452 - val_accuracy: 0.8217
# Epoch 2/100
#  - 11s - loss: 0.0424 - accuracy: 0.8141 - val_loss: 0.0415 - val_accuracy: 0.8217
# Epoch 3/100
#  - 11s - loss: 0.0395 - accuracy: 0.8154 - val_loss: 0.0418 - val_accuracy: 0.8246
# Epoch 4/100
#  - 11s - loss: 0.0379 - accuracy: 0.8136 - val_loss: 0.0396 - val_accuracy: 0.8217
# Epoch 5/100
#  - 11s - loss: 0.0366 - accuracy: 0.8147 - val_loss: 0.0399 - val_accuracy: 0.8268
# Epoch 6/100
#  - 11s - loss: 0.0352 - accuracy: 0.8190 - val_loss: 0.0403 - val_accuracy: 0.8268
# Epoch 7/100
#  - 11s - loss: 0.0344 - accuracy: 0.8192 - val_loss: 0.0404 - val_accuracy: 0.8210
# Epoch 8/100
#  - 11s - loss: 0.0336 - accuracy: 0.8192 - val_loss: 0.0395 - val_accuracy: 0.8254
# Epoch 9/100
#  - 11s - loss: 0.0329 - accuracy: 0.8152 - val_loss: 0.0392 - val_accuracy: 0.8268
# Epoch 10/100
#  - 11s - loss: 0.0323 - accuracy: 0.8118 - val_loss: 0.0385 - val_accuracy: 0.8152
# Epoch 11/100
#  - 11s - loss: 0.0062 - accuracy: 0.9386 - val_loss: 0.0259 - val_accuracy: 0.8543
# Epoch 85/100
#  - 11s - loss: 0.0062 - accuracy: 0.9399 - val_loss: 0.0260 - val_accuracy: 0.8587
# Epoch 86/100
#  - 11s - loss: 0.0062 - accuracy: 0.9371 - val_loss: 0.0266 - val_accuracy: 0.8529
# Epoch 87/100
#  - 11s - loss: 0.0062 - accuracy: 0.9344 - val_loss: 0.0269 - val_accuracy: 0.8529
# Epoch 88/100
#  - 11s - loss: 0.0063 - accuracy: 0.9342 - val_loss: 0.0267 - val_accuracy: 0.8514
# Epoch 89/100
#  - 11s - loss: 0.0060 - accuracy: 0.9418 - val_loss: 0.0267 - val_accuracy: 0.8558
# Epoch 90/100
#  - 11s - loss: 0.0061 - accuracy: 0.9429 - val_loss: 0.0264 - val_accuracy: 0.8529
# Epoch 91/100
#  - 11s - loss: 0.0060 - accuracy: 0.9389 - val_loss: 0.0270 - val_accuracy: 0.8486
# Epoch 92/100
#  - 11s - loss: 0.0060 - accuracy: 0.9386 - val_loss: 0.0268 - val_accuracy: 0.8551
# Epoch 93/100
#  - 11s - loss: 0.0061 - accuracy: 0.9373 - val_loss: 0.0267 - val_accuracy: 0.8529
# Epoch 94/100
#  - 11s - loss: 0.0061 - accuracy: 0.9382 - val_loss: 0.0262 - val_accuracy: 0.8572
# Epoch 95/100
#  - 11s - loss: 0.0060 - accuracy: 0.9382 - val_loss: 0.0265 - val_accuracy: 0.8536
# Epoch 96/100
#  - 11s - loss: 0.0060 - accuracy: 0.9409 - val_loss: 0.0266 - val_accuracy: 0.8551
# Epoch 97/100
#  - 11s - loss: 0.0059 - accuracy: 0.9408 - val_loss: 0.0270 - val_accuracy: 0.8514
# Epoch 98/100
#  - 11s - loss: 0.0060 - accuracy: 0.9400 - val_loss: 0.0271 - val_accuracy: 0.8449
# Epoch 99/100
#  - 11s - loss: 0.0059 - accuracy: 0.9415 - val_loss: 0.0266 - val_accuracy: 0.8500
# Epoch 100/100
#  - 11s - loss: 0.0060 - accuracy: 0.9409 - val_loss: 0.0265 - val_accuracy: 0.8572
# 780/780 [==============================] - 2s 2ms/step
# Test Score: 0.027861261702118775
# Test Accuracy: 0.8474358916282654

# %% [markdown]
# #### 6.2 Output by rbind

# %%
# predict single row
def padding_single_c(dev):
    X_test = dev.filter(['round','round_label','texts'])
    X1_test = X_test['texts']
#     X1_test = [str (item) for item in X1_test]
    X2_test = X_test[['round','round_label']].values
    
    x_test_seq = c_token.texts_to_sequences([X1_test])
    X1_test = sequence.pad_sequences(x_test_seq, maxlen = 150)
    
    return X1_test, X2_test

def padding_single_h(dev):
    X_test = dev.filter(['round','round_label','texts'])
    X1_test = X_test['texts']
#     X1_test = [str (item) for item in X1_test]
    X2_test = X_test[['round','round_label']].values
    
    x_test_seq = h_token.texts_to_sequences([X1_test])
    X1_test = sequence.pad_sequences(x_test_seq, maxlen = 150)
    
    return X1_test, X2_test

# %%
from itertools import chain

# input the development dataframe and the method
# for current models (loss = jsd):
# model_1 = customer model (CNN_c_model, lstm_c_model)
# model_2 = helpdesk model (CNN_h_model, lstm_h_model)
def Generate_submission(dev, model_1, model_2):
    Id_list = dev['id'].unique()
    C_nugget = ['CNUG','CNUG*','CNUG0','CNaN']
    H_nugget = ['HNUG','HNUG*','HNaN']

    final = []
    
    # go through each Id first
    for Id in tqdm(Id_list):  
        result = []
        
        for i in range(len(dev)):
            
            # if Id is match than predict the prob_distribution and zip it as dictionary 
            if dev['id'][i] == Id:
                if dev.iloc[i, 1] == 'customer':
                    t1, t2 = padding_single_c(dev.iloc[i])
                    t2 = np.array(t2).reshape(1,2)
                    cus_prob = model_1.predict(x=[t1, t2])
                    cus_prob = cus_prob.tolist()
                    cus_prob = list(chain(*cus_prob))
                    dict_c = dict(zip(C_nugget, cus_prob))
                    result.append(dict_c)
                else:
                    t3, t4 = padding_single_h(dev.iloc[i])
                    t4 = np.array(t4).reshape(1,2)
                    help_prob = model_2.predict(x=[t3, t4])
                    help_prob = help_prob.tolist()
                    help_prob = list(chain(*help_prob))
                    dict_h = dict(zip(H_nugget, help_prob))
                    result.append(dict_h)
            # if Id isn't match than continue until it match or switch to new Id
            else:
                continue
        
        # Submission form
        dict1 = {'nugget':result,'id':Id}
        final.append(dict1)
        
    return final

# %%
final = Generate_submission(dev, lstm_c_model, lstm_h_model)
# Out:
# C:\Users\doudi\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   from ipykernel import kernelapp as app
# HBox(children=(FloatProgress(value=0.0, max=390.0), HTML(value='')))

# %%
final
# Out:
# [{'nugget': [{'CNUG': 0.000470252736704424,
#     'CNUG*': 2.8830916107835947e-06,
#     'CNUG0': 0.8798546195030212,
#     'CNaN': 0.1196722462773323},
#    {'HNUG': 0.31223055720329285,
#     'HNUG*': 0.0029986384324729443,
#     'HNaN': 0.6847708225250244},
#    {'CNUG': 0.47035953402519226,
#     'CNUG*': 0.03247697651386261,
#     'CNUG0': 0.0010873944265767932,
#     'CNaN': 0.4960760772228241},
#    {'HNUG': 0.2505452334880829,
#     'HNUG*': 0.003138170577585697,
#     'HNaN': 0.7463165521621704}],
#   'id': '4227729258237823'},
#  {'nugget': [{'CNUG': 0.025972850620746613,
#     'CNUG*': 0.00023109630274120718,
#     'CNUG0': 0.8228551745414734,
#     'CNaN': 0.1509409099817276},
#    {'HNUG': 0.3585042953491211,
#     'HNUG*': 0.5592086315155029,
#     'HNaN': 0.08228705078363419},
#    {'CNUG': 0.6785674691200256,
#     'CNUG*': 0.070972740650177,
#     'CNUG0': 0.003589578904211521,
#     'CNaN': 0.2468702495098114},
#    {'HNUG': 0.4449242055416107,
#     'HNUG*': 0.05284923315048218,
#     'HNaN': 0.5022265911102295},
#    {'CNUG': 0.4161052107810974,
#     'CNUG*': 0.043374739587306976,
#     'CNUG0': 0.0009659184142947197,
#     'CNaN': 0.5395541191101074},
#    {'HNUG': 0.5784522294998169,
#     'HNUG*': 0.14906637370586395,
#     'HNaN': 0.27248141169548035},
#    {'CNUG': 0.35774925351142883,
#     'CNUG*': 0.29401323199272156,
#     'CNUG0': 0.00057045160792768,
#     'CNaN': 0.34766706824302673}],
#   'id': '4121001149457182'},
#  {'nugget': [{'CNUG': 7.970385922817513e-05,
#     'CNUG*': 7.04409728768951e-07,
#     'CNUG0': 0.9468110799789429,
#     'CNaN': 0.05310855060815811},
#    {'HNUG': 0.4294689893722534,
#     'HNUG*': 0.506736159324646,
#     'HNaN': 0.06379488110542297},
#    {'CNUG': 0.8418150544166565,
#     'CNUG*': 0.000350581161910668,
#     'CNUG0': 0.013791973702609539,
#     'CNaN': 0.14404232800006866},
#    {'HNUG': 0.800316333770752,
#     'HNUG*': 0.0005013653426431119,
#     'HNaN': 0.19918230175971985},
#    {'CNUG': 0.7942814826965332,
#     'CNUG*': 0.00016601850802544504,
#     'CNUG0': 0.013415502384305,
#     'CNaN': 0.1921370029449463},
#    {'HNUG': 0.47601237893104553,
#     'HNUG*': 0.2829553484916687,
#     'HNaN': 0.24103228747844696}],
#   'id': '3836557276821054'},
#  {'nugget': [{'CNUG': 0.00012733103358186781,
#     'CNUG*': 1.0239554057989153e-06,
#     'CNUG0': 0.918186604976654,
#     'CNaN': 0.08168498426675797},
#    {'HNUG': 0.7787620425224304,
#     'HNUG*': 0.042503152042627335,
#     'HNaN': 0.17873479425907135},
#    {'CNUG': 0.6858124136924744,
#     'CNUG*': 0.16798490285873413,
#     'CNUG0': 0.005325667560100555,
#     'CNaN': 0.14087697863578796},
#    {'HNUG': 0.8198162317276001,
#     'HNUG*': 0.0004402799822855741,
#     'HNaN': 0.1797434687614441},
#    {'CNUG': 0.48847338557243347,
#     'CNUG*': 0.01490182988345623,
#     'CNUG0': 0.0014775487361475825,
#     'CNaN': 0.4951472878456116}],
#   'id': '4233422010370556'},
#  {'nugget': [{'CNUG': 0.006168110761791468,
#     'CNUG*': 3.269523222115822e-05,
#     'CNUG0': 0.9200228452682495,
#     'CNaN': 0.07377634942531586},
#    {'HNUG': 0.5358834266662598,
#     'HNUG*': 0.35057002305984497,
#     'HNaN': 0.11354658007621765},
#    {'CNUG': 0.6994853019714355,
#     'CNUG*': 0.05253706872463226,
#     'CNUG0': 0.003900944720953703,
#     'CNaN': 0.24407675862312317},
#    {'HNUG': 0.1614522635936737,
#     'HNUG*': 0.0038713114336133003,
#     'HNaN': 0.8346763849258423},
#    {'CNUG': 0.3701896667480469,
#     'CNUG*': 0.3178955912590027,
#     'CNUG0': 0.001210605027154088,
#     'CNaN': 0.31070417165756226},
#    {'HNUG': 0.2284664362668991,
#     'HNUG*': 0.0029912160243839025,
#     'HNaN': 0.7685424089431763}],
#   'id': '4135260461193315'},
#  {'nugget': [{'CNUG': 0.07899663597345352,
#     'CNUG*': 0.0011951717315241694,
#     'CNUG0': 0.7628225088119507,
#     'CNaN': 0.15698575973510742},
#    {'HNUG': 0.7846432328224182,
#     'HNUG*': 0.05965447798371315,
#     'HNaN': 0.15570233762264252}],
#   'id': '4002557929649591'},
#  {'nugget': [{'CNUG': 6.934122939128429e-05,
#     'CNUG*': 6.279650506257894e-07,
#     'CNUG0': 0.9533221125602722,
#     'CNaN': 0.04660796374082565},
#    {'HNUG': 0.6458607316017151,
#     'HNUG*': 0.11740898340940475,
#     'HNaN': 0.23673032224178314},
#    {'CNUG': 0.8765954971313477,
#     'CNUG*': 0.00010666857997421175,
#     'CNUG0': 0.025741076096892357,
#     'CNaN': 0.0975567027926445},
#    {'HNUG': 0.8689042925834656,
#     'HNUG*': 0.00029574043583124876,
#     'HNaN': 0.1308000087738037},
#    {'CNUG': 0.8504273891448975,
#     'CNUG*': 0.00011581250873859972,
#     'CNUG0': 0.02450009249150753,
#   'id': '4209924781874478'},
#  {'nugget': [{'CNUG': 6.9540532422252e-05,
#     'CNUG*': 6.294457648436946e-07,
#     'CNUG0': 0.9531943798065186,
#     'CNaN': 0.04673546180129051},
#    {'HNUG': 0.8374418616294861,
#     'HNUG*': 0.00044591480400413275,
#     'HNaN': 0.16211219131946564},
#    {'CNUG': 0.5845342874526978,
#     'CNUG*': 0.00024254048184957355,
#     'CNUG0': 0.0025023608468472958,
#     'CNaN': 0.41272076964378357},
#    {'HNUG': 0.8067164421081543,
#     'HNUG*': 0.05572417005896568,
#     'HNaN': 0.13755929470062256},
#    {'CNUG': 0.2916211783885956,
#     'CNUG*': 0.4941265285015106,
#     'CNUG0': 0.001078569213859737,
#     'CNaN': 0.21317371726036072},
#    {'HNUG': 0.7606405019760132,
#     'HNUG*': 0.11367154866456985,
#     'HNaN': 0.12568797171115875}],
#   'id': '3802161144120242'},
#  {'nugget': [{'CNUG': 0.029907122254371643,
#     'CNUG*': 0.0014048193115741014,
#     'CNUG0': 0.36314406991004944,
#     'CNaN': 0.6055439114570618},
#    {'HNUG': 0.8359929919242859,
#     'HNUG*': 0.0004748433129861951,
#     'HNaN': 0.16353216767311096},
#    {'CNUG': 0.8441332578659058,
#     'CNUG*': 0.000109926812001504,
#     'CNUG0': 0.01697619818150997,
#     'CNaN': 0.1387806385755539},
#    {'HNUG': 0.7959652543067932,
#     'HNUG*': 0.0005470248870551586,
#     'HNaN': 0.20348764955997467},
#    {'CNUG': 0.4161052107810974,
#     'CNUG*': 0.043374739587306976,
#     'CNUG0': 0.0009659184142947197,
#     'CNaN': 0.5395541191101074}],
#   'id': '3595238251995469'},
#  {'nugget': [{'CNUG': 0.00020788062829524279,
#     'CNUG*': 1.7226348063559271e-06,
# ...
#     'CNUG0': 0.002872524317353964,
#     'CNaN': 0.4233667254447937},
#    {'HNUG': 0.7415825724601746,
#     'HNUG*': 0.0008798518683761358,
#     'HNaN': 0.25753751397132874}],
#   'id': '4169556459153787'},
#  {'nugget': [{'CNUG': 0.04263686761260033,
#     'CNUG*': 0.00020143945585004985,
#     'CNUG0': 0.9014835357666016,
#     'CNaN': 0.05567815527319908},
#    {'HNUG': 0.7153996825218201,
#     'HNUG*': 0.12285561114549637,
#     'HNaN': 0.16174466907978058},
#    {'CNUG': 0.7738566994667053,
#     'CNUG*': 0.00027267602854408324,
#     'CNUG0': 0.008264383301138878,
#     'CNaN': 0.21760621666908264},
#    {'HNUG': 0.7273077368736267,
#     'HNUG*': 0.15832309424877167,
#     'HNaN': 0.11436919867992401}],
#   'id': '4170708147859382'},
#  {'nugget': [{'CNUG': 0.04955358803272247,
#     'CNUG*': 0.00044586267904378474,
#     'CNUG0': 0.8282319903373718,
#     'CNaN': 0.12176848202943802},
#    {'HNUG': 0.6474814414978027,
#     'HNUG*': 0.15011632442474365,
#     'HNaN': 0.20240214467048645}],
#   'id': '4173187002796867'},
#  {'nugget': [{'CNUG': 6.93660622346215e-05,
#     'CNUG*': 6.281497917370871e-07,
#     'CNUG0': 0.9533060789108276,
#     'CNUG*': 1.3116228956278064e-06,
#     'CNUG0': 0.9250441193580627,
#     'CNaN': 0.07479217648506165},
#    {'HNUG': 0.904216468334198,
#     'HNUG*': 0.00023103831335902214,
#     'HNaN': 0.09555250406265259},
#    {'CNUG': 0.5524773597717285,
#     'CNUG*': 0.049525026232004166,
#     'CNUG0': 0.0017613362288102508,
#     'CNaN': 0.3962363004684448},
#    {'HNUG': 0.5712607502937317,
#     'HNUG*': 0.20718325674533844,
#     'HNaN': 0.2215559184551239},
#    {'CNUG': 0.6882482171058655,
#     'CNUG*': 0.00024299869255628437,
#     'CNUG0': 0.006067646201699972,
#     'CNaN': 0.30544114112854004},
#    {'HNUG': 0.5409464240074158,
#     'HNUG*': 0.005570092238485813,
#     'HNaN': 0.4534834623336792},
#    {'CNUG': 0.38431739807128906,
#     'CNUG*': 0.03634054586291313,
#     'CNUG0': 0.0004333161632530391,
#     'CNaN': 0.5789087414741516}],
#   'id': '4232672933535868'},
#  {'nugget': [{'CNUG': 0.0013061849167570472,
#     'CNUG*': 5.038240942667471e-06,
#     'CNUG0': 0.7443486452102661,
#     'CNaN': 0.25434020161628723},
#    {'HNUG': 0.7452978491783142,
#     'HNUG*': 0.000780716072767973,
#     'HNaN': 0.2539214789867401},
#    {'CNUG': 0.2845064103603363,
#     'CNUG*': 0.5915894508361816,
#     'CNUG0': 0.0013658467214554548,
#     'CNaN': 0.12253837287425995},
#    {'HNUG': 0.6487869024276733,
#     'HNUG*': 0.15879857540130615,
#     'HNaN': 0.1924145519733429},
#    {'CNUG': 0.6654440760612488,
#     'CNUG*': 0.00220884894952178,
#     'CNUG0': 0.0044202497228980064,
#     'CNaN': 0.32792678475379944},
#    {'HNUG': 0.552466869354248,
#     'HNUG*': 0.13984088599681854,
#     'HNaN': 0.3076922595500946},
#    {'CNUG': 0.4478681981563568,
#     'CNUG*': 0.00046334476792253554,
#     'CNUG0': 0.0007373933913186193,
#     'CNaN': 0.5509310364723206}],
#   'id': '4233014013184785'}]

# %% [markdown]
# ### 7. Generate the submission estimation JSON

# %%
import json
import time
import os

path = 'C:/Users/doudi/OneDrive/Documents/ntcir15/eval'
os.chdir(path)
timestr = time.strftime("%Y%m%d%H%M")

# %%
with open((timestr + '_' + 'dev_eval.json'), 'w', encoding='utf-8') as f: 
    f.write(json.dumps(final, ensure_ascii=False, indent=2))

# %%
# !python eval.py 202006161922_dev_eval.json dev_cn.json
# Out:
# {'quality': None, 'nugget': {'jsd': 4.5435131098782255, 'rnss': 2.9066604872291197}}

# %%
print('=== 大會的最佳解果 ===')
print('jsd :', 2**(-5.526337576519978))
print('rnss :', 2**(-3.4904552364933963))

print('\n')
print('=== 我們模型結果 ===')
print('jsd :', 2**(-4.5435131098782255))
print('rnss :', 2**(-2.9066604872291197))
# Out:
# === 大會的最佳解果 ===
# jsd : 0.02169734643558826
# rnss : 0.08897505708102076
#
#
# === 我們模型結果 ===
# jsd : 0.04288113463140385
# rnss : 0.13335460155933881

# %% [markdown]
# >> below is the debugging zone.... ignore them plz zzz
