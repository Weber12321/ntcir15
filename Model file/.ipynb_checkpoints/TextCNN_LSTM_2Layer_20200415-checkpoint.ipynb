# %% [markdown]
# # DialEval-1 DNN practice
# ### Model : CNN, LSTM
# ##### input round, sender pred label
# ##### Edited by Weber Huang in 2020-04-15

# %%
import os
import pandas as pd

os.chdir('C:/Users/doudi/OneDrive/Documents/ntcir15/Dataset/DialEval-1')
df = pd.read_excel(r'./200514_dev+train.xlsx')

# %%
tmp = []
for i in df['sender']:
    if i == 'customer':
        tmp.append(0)
    else:
        tmp.append(1)
df['sender_num'] = tmp
df.head()
# Out:
#                  id  round    sender  \
# 0  4227729258237820      1  customer
# 1  4227729258237820      2  helpdesk
# 2  4227729258237820      3  customer
# 3  4227729258237820      4  helpdesk
# 4  4121001149457180      1  customer
#
#                                                texts  max_label  round_label  \
# 0  内涵 段子 联通 皮 点赞 中国联通 中国联通 客服 掌上 营业厅 内涵 段子 话题 封 郑...          3            2
# 1                                                  u          6            4
# 2                                                 夸夸          3            0
# 3                                                  *          6            4
# 4  距离 反映 问题 已经 一个 星期 花粉 助手 D 荣耀 honor 荣耀 手机 华为 终端...          2            2
#
#        CNUG  CNUG*     CNUG0      CNaN      HNUG  HNUG*      HNaN  sender_num
# 0  0.052632    0.0  0.157895  0.789474  0.000000    0.0  0.000000           0
# 1  0.000000    0.0  0.000000  0.000000  0.157895    0.0  0.842105           1
# 2  0.157895    0.0  0.000000  0.842105  0.000000    0.0  0.000000           0
# 3  0.000000    0.0  0.000000  0.000000  0.157895    0.0  0.842105           1
# 4  0.052632    0.0  0.789474  0.157895  0.000000    0.0  0.000000           0

# %%
df['labels'].unique()
# Out:
# array([3, 6, 2, 4, 0, 5, 1], dtype=int64)

# %%
from sklearn.model_selection import train_test_split 
from sklearn import metrics
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.utils import np_utils
from keras import optimizers
from keras.layers.merge import concatenate
from keras.models import Sequential, Model
from keras.layers import Input
from keras.layers import Dense, Embedding
from keras.layers import Convolution1D, Flatten, Dropout, MaxPool1D, GlobalAveragePooling1D
from keras.layers import concatenate
from keras import initializers
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.embeddings import Embedding
# from keras.layers.recurrent import SimpleRNN
from keras.layers.recurrent import LSTM

dev = df[0:1754]
train = df[1755:]

X_train = train.filter(['round','sender_num','texts'])
X_test = dev.filter(['round','sender_num','texts'])
y_train = train.filter(['labels'])
y_test = dev.filter(['labels'])

# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
def CNN(X_train, X_test, y_train, y_test):
    
    X1_train = X_train['texts']
#     X1_train = X_train[:,[-1]]
    X1_train = [str (item) for item in X1_train]
    
    X1_test = X_test['texts']
#     X1_test = X_test[:,[-1]]
    X1_test = [str (item) for item in X1_test]

    X2_train = X_train[['round','sender_num']].values
#     X2_train = X_train[:,0:7]
    X2_test = X_test[['round','sender_num']].values
#     X2_test = X_test[:,0:7]
    
    token = Tokenizer(num_words = 20000)
    token.fit_on_texts(X1_train)
    vocab = token.word_index
    print(token.document_count)

    x_train_seq = token.texts_to_sequences(X1_train)
    x_test_seq = token.texts_to_sequences(X1_test)
    X1_train = sequence.pad_sequences(x_train_seq, maxlen = 150)
    X1_test = sequence.pad_sequences(x_test_seq, maxlen = 150)

    y_one_train = np_utils.to_categorical(y_train)
    y_one_test = np_utils.to_categorical(y_test)
     
    num_labels = 7
    main_input = Input(shape=(150,), dtype='float64')

    sub_input = Input(shape=(2,))
    
    # pre-train embeddings
    # embedder = Embedding(len(vocab) + 1, 300, input_length = 20, weights = [embedding_matrix], trainable = False)
    # embed = embedder(main_input)
    embed = Embedding(len(vocab)+1, 300, input_length=150)(main_input)
    # filter size, region size
    cnn = Convolution1D(2, 2, padding='same', strides = 1, activation='relu')(embed)
    cnn = MaxPool1D(pool_size=4)(cnn)
    flat = Flatten()(cnn)
    drop = Dropout(0.2)(flat)
    # main_output = Dense(num_labels, activation='sigmoid')(drop)


    dense_1 = Dense(units=256,activation='relu')(sub_input)
    drop_1 = Dropout(0.35)(dense_1)
    dense_2 = Dense(units=128,activation='relu')(drop_1)
    # sub_output = Dense(units=2,activation='sigmoid')(dense_2)

    merge = concatenate([drop, dense_2])
    dense_3 = Dense(units=10, activation='relu')(merge)
    output = Dense(units=7, activation='softmax')(dense_3)

    model = Model(inputs=[main_input, sub_input], outputs=output)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    print(model.summary())

    # checkpoint
    # filepath="C:/Users/doudi/OneDrive/Documents/TMU-GIDS/Lab/Competition/AI cup 2019/weights.best.hdf5"
    # checkpoint= ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    train_history = model.fit(x=[X1_train, X2_train], y=y_one_train, epochs=10, 
                              batch_size=32, verbose=1, validation_split=0.2)

    score = model.evaluate(x=[X1_test, X2_test], y=y_one_test, verbose=1)

    print("Test Score:", score[0])
    print("Test Accuracy:", score[1])

    pre_probability = model.predict(x=[X1_test, X2_test])
    predicted = pre_probability.argmax(axis=-1)

    from sklearn import metrics
    print("Classification report for classifier:\n%s\n"
          % ( metrics.classification_report(y_test, predicted)))

    print("f1_score :\n%s\n" % ( metrics.f1_score(y_test, predicted, average='macro')))
    print("acc_score :\n%s\n" % ( metrics.accuracy_score(y_test, predicted)))

    return train_history

# %%
import numpy as np
from tqdm import tqdm_notebook as tqdm


CNN(X_train, X_test, y_train, y_test)

'''
n_folds = 3
model_history = []
for i in tqdm(range(n_folds)):
    print("Training on Fold: ",i+1)
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, 
                                                        random_state = np.random.randint(1,1000, 1)[0])
                                               
    
    model_history.append(CNN(X_train, X_test, y_train, y_test))
    print("======="*12, end="\n\n\n")
'''
# Out:
# 15400
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            (None, 150)          0
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 150, 300)     4940100     input_9[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150, 2)       1202        embedding_5[0][0]
# __________________________________________________________________________________________________
# input_10 (InputLayer)           (None, 2)            0
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 37, 2)        0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 256)          768         input_10[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 74)           0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 256)          0           dense_17[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 74)           0           flatten_5[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 128)          32896       dropout_10[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 202)          0           dropout_9[0][0]
#                                                                  dense_18[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 10)           2030        concatenate_5[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 7)            77          dense_19[0][0]
# ==================================================================================================
# Total params: 4,977,073
# Trainable params: 4,977,073
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Train on 12320 samples, validate on 3080 samples
# Epoch 1/10
# 12320/12320 [==============================] - 5s 368us/step - loss: 0.7401 - accuracy: 0.8037 - val_loss: 0.4431 - val_accuracy: 0.8750
# Epoch 2/10
# 12320/12320 [==============================] - 4s 340us/step - loss: 0.4698 - accuracy: 0.8512 - val_loss: 0.4034 - val_accuracy: 0.8808
# Epoch 3/10
# 12320/12320 [==============================] - 4s 338us/step - loss: 0.4190 - accuracy: 0.8560 - val_loss: 0.3948 - val_accuracy: 0.8815
# Epoch 4/10
# 12320/12320 [==============================] - 4s 337us/step - loss: 0.3883 - accuracy: 0.8591 - val_loss: 0.3883 - val_accuracy: 0.8802
# Epoch 5/10
# 12320/12320 [==============================] - 4s 339us/step - loss: 0.3611 - accuracy: 0.8660 - val_loss: 0.3912 - val_accuracy: 0.8779
# Epoch 6/10
# 12320/12320 [==============================] - 4s 339us/step - loss: 0.3393 - accuracy: 0.8698 - val_loss: 0.4007 - val_accuracy: 0.8802
# Epoch 7/10
# 12320/12320 [==============================] - 4s 338us/step - loss: 0.3247 - accuracy: 0.8708 - val_loss: 0.4078 - val_accuracy: 0.8685
# Epoch 8/10
# 12320/12320 [==============================] - 4s 338us/step - loss: 0.3115 - accuracy: 0.8753 - val_loss: 0.4224 - val_accuracy: 0.8695
# Epoch 9/10
# 12320/12320 [==============================] - 4s 338us/step - loss: 0.3016 - accuracy: 0.8804 - val_loss: 0.4465 - val_accuracy: 0.8653
# Epoch 10/10
# 12320/12320 [==============================] - 4s 338us/step - loss: 0.2929 - accuracy: 0.8809 - val_loss: 0.4565 - val_accuracy: 0.8633
# 1754/1754 [==============================] - 0s 65us/step
# Test Score: 0.5059759783704033
# Test Accuracy: 0.8551881313323975
# Classification report for classifier:
#               precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88       477
#            1       0.00      0.00      0.00        23
#            2       0.96      0.98      0.97       374
#            3       0.27      0.15      0.19       100
#            4       0.88      0.97      0.92       662
#            5       0.29      0.15      0.20        33
#            6       0.75      0.28      0.41        85
#
#     accuracy                           0.86      1754
#    macro avg       0.57      0.50      0.51      1754
# weighted avg       0.82      0.86      0.83      1754
#
#
# f1_score :
# 0.5112063495823634
#
# acc_score :
# 0.855188141391106
# '\nn_folds = 3\nmodel_history = []\nfor i in tqdm(range(n_folds)):\n    print("Training on Fold: ",i+1)\n    from sklearn.model_selection import train_test_split\n    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, \n                                                        random_state = np.random.randint(1,1000, 1)[0])\n                                               \n    \n    model_history.append(CNN(X_train, X_test, y_train, y_test))\n    print("======="*12, end="\n\n\n")\n'

# %%
def lstm(X_train, X_test, y_train, y_test):
    X1_train = X_train['texts']
#     X1_train = X_train[:,[-1]]
    X1_train = [str (item) for item in X1_train]
    
    X1_test = X_test['texts']
#     X1_test = X_test[:,[-1]]
    X1_test = [str (item) for item in X1_test]

    X2_train = X_train[['round','sender_num']].values
#     X2_train = X_train[:,0:7]
    X2_test = X_test[['round','sender_num']].values
#     X2_test = X_test[:,0:7]
    
    token = Tokenizer(num_words = 20000)
    token.fit_on_texts(X1_train)
    print(token.document_count)

    x_train_seq = token.texts_to_sequences(X1_train)
    x_test_seq = token.texts_to_sequences(X1_test)
    X1_train = sequence.pad_sequences(x_train_seq, maxlen = 150)
    X1_test = sequence.pad_sequences(x_test_seq, maxlen = 150)

    y_one_train = np_utils.to_categorical(y_train)
    y_one_test = np_utils.to_categorical(y_test)
     
    main_input = Input(shape=(150,), dtype='float64')
    sub_input = Input(shape=(2,))
    
    embed = Embedding(output_dim=32,input_dim=20000,input_length=150)(main_input)
    dropout_1 = Dropout(0.35)(embed)
    lst = LSTM(units=16)(dropout_1)
    dense_1 = Dense(units=256,activation='relu')(lst)
    dropout_2 = Dropout(0.35)(dense_1)
    dense_2 = Dense(units=128,activation='relu')(dropout_2)
    dense_3 = Dense(units=7,activation='softmax')(dense_2)


    dense_4 = Dense(units=256,activation='relu')(sub_input)
    dropout_3 = Dropout(0.35)(dense_4)
    dense_5 = Dense(units=128,activation='relu')(dropout_3)
    # sub_output = Dense(units=2,activation='sigmoid')(dense_2)

    merge = concatenate([dense_3, dense_5])
    dense_6 = Dense(units=10, activation='relu')(merge)
    output = Dense(units=7, activation='softmax')(dense_6)

    model = Model(inputs=[main_input, sub_input], outputs=output)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    print(model.summary())

    # checkpoint
    # filepath="C:/Users/doudi/OneDrive/Documents/TMU-GIDS/Lab/Competition/AI cup 2019/weights.best.hdf5"
    # checkpoint= ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    train_history = model.fit(x=[X1_train, X2_train], y=y_one_train, epochs=10, 
                              batch_size=128, verbose=1, validation_split=0.2)

    score = model.evaluate(x=[X1_test, X2_test], y=y_one_test, verbose=1)

    print("Test Score:", score[0])
    print("Test Accuracy:", score[1])

    pre_probability = model.predict(x=[X1_test, X2_test])
    predicted = pre_probability.argmax(axis=-1)

    from sklearn import metrics
    print("Classification report for classifier:\n%s\n"
          % ( metrics.classification_report(y_test, predicted)))

    print("f1_score :\n%s\n" % ( metrics.f1_score(y_test, predicted, average='macro')))
    print("acc_score :\n%s\n" % ( metrics.accuracy_score(y_test, predicted)))

    return train_history

# %%
lstm(X_train, X_test, y_train, y_test)
# Out:
# 15400
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           (None, 150)          0
# __________________________________________________________________________________________________
# embedding_6 (Embedding)         (None, 150, 32)      640000      input_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 150, 32)      0           embedding_6[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 16)           3136        dropout_11[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 256)          4352        lstm_1[0][0]
# __________________________________________________________________________________________________
# input_12 (InputLayer)           (None, 2)            0
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 256)          0           dense_21[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 256)          768         input_12[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 128)          32896       dropout_12[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 256)          0           dense_24[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 7)            903         dense_22[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 128)          32896       dropout_13[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 135)          0           dense_23[0][0]
#                                                                  dense_25[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 10)           1360        concatenate_6[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 7)            77          dense_26[0][0]
# ==================================================================================================
# Total params: 716,388
# Trainable params: 716,388
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Train on 12320 samples, validate on 3080 samples
# Epoch 1/10
# 12320/12320 [==============================] - 13s 1ms/step - loss: 1.0976 - accuracy: 0.6578 - val_loss: 0.7518 - val_accuracy: 0.8672
# Epoch 2/10
# 12320/12320 [==============================] - 12s 957us/step - loss: 0.6617 - accuracy: 0.8477 - val_loss: 0.4859 - val_accuracy: 0.8672
# Epoch 3/10
# 12320/12320 [==============================] - 12s 956us/step - loss: 0.5021 - accuracy: 0.8489 - val_loss: 0.4400 - val_accuracy: 0.8672
# Epoch 4/10
# 12320/12320 [==============================] - 12s 972us/step - loss: 0.4344 - accuracy: 0.8527 - val_loss: 0.4012 - val_accuracy: 0.8792
# Epoch 5/10
# 12320/12320 [==============================] - 12s 965us/step - loss: 0.3793 - accuracy: 0.8660 - val_loss: 0.4125 - val_accuracy: 0.8484
# Epoch 6/10
# 12320/12320 [==============================] - 12s 973us/step - loss: 0.3529 - accuracy: 0.8804 - val_loss: 0.3947 - val_accuracy: 0.8906
# Epoch 7/10
# 12320/12320 [==============================] - 12s 966us/step - loss: 0.3349 - accuracy: 0.8907 - val_loss: 0.4006 - val_accuracy: 0.8701
# Epoch 8/10
# 12320/12320 [==============================] - 12s 972us/step - loss: 0.3183 - accuracy: 0.8979 - val_loss: 0.4019 - val_accuracy: 0.8792
# Epoch 9/10
# 12320/12320 [==============================] - 12s 967us/step - loss: 0.3059 - accuracy: 0.9033 - val_loss: 0.4222 - val_accuracy: 0.8773
# Epoch 10/10
# 12320/12320 [==============================] - 12s 963us/step - loss: 0.2983 - accuracy: 0.9084 - val_loss: 0.4097 - val_accuracy: 0.8669
# 1754/1754 [==============================] - 3s 2ms/step
# Test Score: 0.42703837667726735
# Test Accuracy: 0.8494868874549866
# Classification report for classifier:
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86       477
#            1       0.00      0.00      0.00        23
#            2       0.97      0.95      0.96       374
#            3       0.26      0.33      0.29       100
#            4       0.91      0.96      0.93       662
#            5       0.00      0.00      0.00        33
#            6       0.67      0.64      0.65        85
#
#     accuracy                           0.85      1754
#    macro avg       0.52      0.53      0.53      1754
# weighted avg       0.83      0.85      0.84      1754
#
#
# f1_score :
# 0.5278326687517787
#
# acc_score :
# 0.8494868871151653
# C:\Users\doudi\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\doudi\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
