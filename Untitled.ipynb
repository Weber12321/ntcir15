# %%
import os
import pandas as pd
from gensim.models import word2vec
import pickle

# %%
os.chdir('C:\\Users\\doudi\\Downloads\\baidu_256_500k')
f = pd.read_pickle('baidu_256_500k.pkl')
word2vec=pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_pickle(path, compression)
#     154             warnings.simplefilter("ignore", Warning)
# --> 155             return pickle.load(f)
#     156     except Exception:  # noqa: E722
#
# MemoryError:
#
# During handling of the above exception, another exception occurred:
#
# MemoryError                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_pickle(path, compression)
#     157         try:
# --> 158             return pc.load(f, encoding=None)
#     159         except Exception:  # noqa: E722
#
# ~\Anaconda3\lib\site-packages\pandas\compat\pickle_compat.py in load(fh, encoding, is_verbose)
#     218
# --> 219         return up.load()
#     220     except (ValueError, TypeError):
#
# ~\Anaconda3\lib\pickle.py in load(self)
#    1084                 assert isinstance(key, bytes_types)
# -> 1085                 dispatch[key[0]](self)
#    1086         except _Stop as stopinst:
#
# ~\Anaconda3\lib\pickle.py in load_frame(self)
#    1111             raise ValueError("frame size > sys.maxsize: %d" % frame_size)
# -> 1112         self._unframer.load_frame(frame_size)
#    1113     dispatch[FRAME[0]] = load_frame
#
# ~\Anaconda3\lib\pickle.py in load_frame(self, frame_size)
#     283                 "beginning of a new frame before end of current frame")
# --> 284         self.current_frame = io.BytesIO(self.file_read(frame_size))
#     285
#
# MemoryError:
#
# During handling of the above exception, another exception occurred:
#
# MemoryError                               Traceback (most recent call last)
# <ipython-input-17-b96cc21d1ccc> in <module>
#       1 os.chdir('C:\\Users\\doudi\\Downloads\\baidu_256_500k')
# ----> 2 f = pd.read_pickle('baidu_256_500k.pkl')
#       3 word2vec=pickle.load(f)
#
# ~\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_pickle(path, compression)
#     158             return pc.load(f, encoding=None)
#     159         except Exception:  # noqa: E722
# --> 160             return pc.load(f, encoding="latin1")
#     161     finally:
#     162         f.close()
#
# ~\Anaconda3\lib\site-packages\pandas\compat\pickle_compat.py in load(fh, encoding, is_verbose)
#     217         up.is_verbose = is_verbose
#     218
# --> 219         return up.load()
#     220     except (ValueError, TypeError):
#     221         raise
#
# ~\Anaconda3\lib\pickle.py in load(self)
#    1083                     raise EOFError
#    1084                 assert isinstance(key, bytes_types)
# -> 1085                 dispatch[key[0]](self)
#    1086         except _Stop as stopinst:
#    1087             return stopinst.value
#
# ~\Anaconda3\lib\pickle.py in load_setitems(self)
#    1527         dict = self.stack[-1]
#    1528         for i in range(0, len(items), 2):
# -> 1529             dict[items[i]] = items[i + 1]
#    1530     dispatch[SETITEMS[0]] = load_setitems
#    1531
#
# MemoryError:
